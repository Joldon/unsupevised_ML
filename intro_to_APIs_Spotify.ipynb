# %%
# https://spotipy.readthedocs.io/en/2.19.0/

# Install spotipy
# As google colab starts each session like a new computer, we must install this each time.
# If you are working on your local machine, you only need to install it once.
# !pip install spotipy --upgrade
# !pip install urllib3 --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.9/dist-packages (from spotipy) (1.26.15)
# Collecting redis>=3.5.3
#   Downloading redis-4.5.4-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.9/dist-packages (from spotipy) (2.27.1)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spotipy) (1.16.0)
# Collecting async-timeout>=4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-4.0.2 redis-4.5.4 spotipy-2.23.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (1.26.15)

# %%
import pandas as pd

# %% [markdown]
# ## Requests
#
# The requests library is the de facto standard for making HTTP requests in Python. It abstracts the complexities of making requests behind a beautiful, simple API so that you can focus on interacting with services and consuming data in your application.
#
# https://requests.readthedocs.io/en/latest/
#
# When we make a request, we get a requests.Response object in return. The requests.Response object contains the server's response to the HTTP request. Part of this response is a number - which represents whether we received the information we wanted or not. If you get a number that you don't understand, these cats will help you: https://http.cat/
#
# More often than not you'll receive:
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

wbscs = requests.get("https://www.wbscodingschool.com/")
print("WBS CS: ", wbscs.status_code)
# Out:
# Google: 200
# NBA: 401
# WBS CS:  403

# %% [markdown]
# ## JSON

# %% [markdown]
# ### Intro - making a request and viewing the JSON
#
# https://docs.python.org/3/library/json.html
#
# Since its inception, JSON has quickly become the de facto standard for information exchange. JSON supports primitive types, like strings and numbers, as well as nested lists and objects. It looks like nested python dictionaries:
#
# `{"firstname": "Harry",
# "lastname": "Noah",
# "city": "Berlin",
# "dogs": [{"name": "rover", "breed": "labrador"}, {"name": "pip", "breed": "spaniel"}],
# "cars": "none"}`

# %%
import json

# %%
# Make the request.
response = requests.get("https://jsonplaceholder.typicode.com/users")

# %%
# Check the HTTP code.
response
# Out:
# <Response [200]>

# %%
# Example of what a JSON looks like.

# View API response as a JSON.
response.json()
# Out:
# [{'id': 1,
#   'name': 'Leanne Graham',
#   'username': 'Bret',
#   'email': 'Sincere@april.biz',
#   'address': {'street': 'Kulas Light',
#    'suite': 'Apt. 556',
#    'city': 'Gwenborough',
#    'zipcode': '92998-3874',
#    'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#   'phone': '1-770-736-8031 x56442',
#   'website': 'hildegard.org',
#   'company': {'name': 'Romaguera-Crona',
#    'catchPhrase': 'Multi-layered client-server neural-net',
#    'bs': 'harness real-time e-markets'}},
#  {'id': 2,
#   'name': 'Ervin Howell',
#   'username': 'Antonette',
#   'email': 'Shanna@melissa.tv',
#   'address': {'street': 'Victor Plains',
#    'suite': 'Suite 879',
#    'city': 'Wisokyburgh',
#    'zipcode': '90566-7771',
#    'geo': {'lat': '-43.9509', 'lng': '-34.4618'}},
#   'phone': '010-692-6593 x09125',
#   'website': 'anastasia.net',
#   'company': {'name': 'Deckow-Crist',
#    'catchPhrase': 'Proactive didactic contingency',
#    'bs': 'synergize scalable supply-chains'}},
#  {'id': 3,
#   'name': 'Clementine Bauch',
#   'username': 'Samantha',
#   'email': 'Nathan@yesenia.net',
#   'address': {'street': 'Douglas Extension',
#    'suite': 'Suite 847',
#    'city': 'McKenziehaven',
#    'zipcode': '59590-4157',
#    'geo': {'lat': '-68.6102', 'lng': '-47.0653'}},
#   'phone': '1-463-123-4447',
#   'website': 'ramiro.info',
#   'company': {'name': 'Romaguera-Jacobson',
#    'catchPhrase': 'Face to face bifurcated interface',
#    'bs': 'e-enable strategic applications'}},
#  {'id': 4,
#   'name': 'Patricia Lebsack',
#   'username': 'Karianne',
#   'email': 'Julianne.OConner@kory.org',
#   'address': {'street': 'Hoeger Mall',
#    'suite': 'Apt. 692',
#    'city': 'South Elvis',
#    'zipcode': '53919-4257',
#    'geo': {'lat': '29.4572', 'lng': '-164.2990'}},
#   'phone': '493-170-9623 x156',
#   'website': 'kale.biz',
#   'company': {'name': 'Robel-Corkery',
#    'catchPhrase': 'Multi-tiered zero tolerance productivity',
#    'bs': 'transition cutting-edge web services'}},
#  {'id': 5,
#   'name': 'Chelsey Dietrich',
#   'username': 'Kamren',
#   'email': 'Lucio_Hettinger@annie.ca',
#   'address': {'street': 'Skiles Walks',
#    'suite': 'Suite 351',
#    'city': 'Roscoeview',
#    'zipcode': '33263',
#    'geo': {'lat': '-31.8129', 'lng': '62.5342'}},
#   'phone': '(254)954-1289',
#   'website': 'demarco.info',
#   'company': {'name': 'Keebler LLC',
#    'catchPhrase': 'User-centric fault-tolerant solution',
#    'bs': 'revolutionize end-to-end systems'}},
#  {'id': 6,
#   'name': 'Mrs. Dennis Schulist',
#   'username': 'Leopoldo_Corkery',
#   'email': 'Karley_Dach@jasper.info',
#   'address': {'street': 'Norberto Crossing',
#    'suite': 'Apt. 950',
#    'city': 'South Christy',
#    'zipcode': '23505-1337',
#    'geo': {'lat': '-71.4197', 'lng': '71.7478'}},
#   'phone': '1-477-935-8478 x6430',
#   'website': 'ola.org',
#   'company': {'name': 'Considine-Lockman',
#    'catchPhrase': 'Synchronised bottom-line interface',
#    'bs': 'e-enable innovative applications'}},
#  {'id': 7,
#   'name': 'Kurtis Weissnat',
#   'username': 'Elwyn.Skiles',
#   'email': 'Telly.Hoeger@billy.biz',
#   'address': {'street': 'Rex Trail',
#    'suite': 'Suite 280',
#    'city': 'Howemouth',
#    'zipcode': '58804-1099',
#    'geo': {'lat': '24.8918', 'lng': '21.8984'}},
#   'phone': '210.067.6132',
#   'website': 'elvis.io',
#   'company': {'name': 'Johns Group',
#    'catchPhrase': 'Configurable multimedia task-force',
#    'bs': 'generate enterprise e-tailers'}},
#  {'id': 8,
#   'name': 'Nicholas Runolfsdottir V',
#   'username': 'Maxime_Nienow',
#   'email': 'Sherwood@rosamond.me',
#   'address': {'street': 'Ellsworth Summit',
#    'suite': 'Suite 729',
#    'city': 'Aliyaview',
#    'zipcode': '45169',
#    'geo': {'lat': '-14.3990', 'lng': '-120.7677'}},
#   'phone': '586.493.6943 x140',
#   'website': 'jacynthe.com',
#   'company': {'name': 'Abernathy Group',
#    'catchPhrase': 'Implemented secondary concept',
#    'bs': 'e-enable extensible e-tailers'}},
#  {'id': 9,
#   'name': 'Glenna Reichert',
#   'username': 'Delphine',
#   'email': 'Chaim_McDermott@dana.io',
#   'address': {'street': 'Dayna Park',
#    'suite': 'Suite 449',
#    'city': 'Bartholomebury',
#    'zipcode': '76495-3109',
#    'geo': {'lat': '24.6463', 'lng': '-168.8889'}},
#   'phone': '(775)976-6794 x41206',
#   'website': 'conrad.com',
#   'company': {'name': 'Yost and Sons',
#    'catchPhrase': 'Switchable contextually-based project',
#    'bs': 'aggregate real-time technologies'}},
#  {'id': 10,
#   'name': 'Clementina DuBuque',
#   'username': 'Moriah.Stanton',
#   'email': 'Rey.Padberg@karina.biz',
#   'address': {'street': 'Kattie Turnpike',
#    'suite': 'Suite 198',
#    'city': 'Lebsackbury',
#    'zipcode': '31428-2261',
#    'geo': {'lat': '-38.2386', 'lng': '57.2232'}},
#   'phone': '024-648-3804',
#   'website': 'ambrose.net',
#   'company': {'name': 'Hoeger LLC',
#    'catchPhrase': 'Centralized empowering task-force',
#    'bs': 'target end-to-end models'}}]

# %% [markdown]
# ### GitHub API - Accessing the data in the JSON
#
# Now that we know
# - what an API is,
# - how to request information from one (requests),
# - how the information will be delivered to us (JSON):
#
# Let's look how we can use this information. We will first look at how we can access particular values within the JSON. Then we will look at a couple of methods to make a dataframe from the JSON.
#
# Github has many APIs. Here we'll look at two of them.

# %%
# Very basic API (a string returned).

# GitHub's Zen API produces a new inspirational phrase every 30 seconds.
# Run this cell again in 30 seconds to see a different output.

resp = requests.get("https://api.github.com/zen")
resp.text
# Out:
# 'Approachable is better than simple.'

# %%
# More complex API (a large json returned).

# Github's Event API shows the events that power the various activity streams on the site.
# In other words, what's happening on Github, who's updating what?

response = requests.get('https://api.github.com/events')
github_response = response.json()
github_response
# Out:
# [{'id': '28396254892',
#   'type': 'PushEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 235323015,
#    'name': 'SAP/inquirer-gui',
#    'url': 'https://api.github.com/repos/SAP/inquirer-gui'},
#   'payload': {'repository_id': 235323015,
#    'push_id': 13289076324,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dependabot/npm_and_yarn/folder-browser-plugin/follow-redirects-1.15.2',
#    'head': '458d3af8cc741f80a87a4717af9051e18808a2cd',
#    'before': '382cc32b5d5fc82b75addac333de688ab36ef16d',
#    'commits': [{'sha': 'e10428264090fa822c34b98e5d9112ff5369aaf9',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'chore: bump minimist and mkdirp in /sample-vscode-extension (#577)\n\nBumps [minimist](https://github.com/minimistjs/minimist) and [mkdirp](https://github.com/isaacs/node-mkdirp). These dependencies needed to be updated together.\r\n\r\nUpdates `minimist` from 0.0.8 to 1.2.8\r\n- [Release notes](https://github.com/minimistjs/minimist/releases)\r\n- [Changelog](https://github.com/minimistjs/minimist/blob/main/CHANGELOG.md)\r\n- [Commits](https://github.com/minimistjs/minimist/compare/v0.0.8...v1.2.8)\r\n\r\nUpdates `mkdirp` from 0.5.1 to 0.5.6\r\n- [Release notes](https://github.com/isaacs/node-mkdirp/releases)\r\n- [Changelog](https://github.com/isaacs/node-mkdirp/blob/main/CHANGELOG.md)\r\n- [Commits](https://github.com/isaacs/node-mkdirp/compare/0.5.1...v0.5.6)\r\n\r\n---\r\nupdated-dependencies:\r\n- dependency-name: minimist\r\n  dependency-type: indirect\r\n- dependency-name: mkdirp\r\n  dependency-type: indirect\r\n...\r\n\r\nSigned-off-by: dependabot[bot] <support@github.com>\r\nCo-authored-by: dependabot[bot] <49699333+dependabot[bot]@users.noreply.github.com>\r\nCo-authored-by: Rima Sirich <rima.sirich@sap.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/SAP/inquirer-gui/commits/e10428264090fa822c34b98e5d9112ff5369aaf9'},
#     {'sha': '458d3af8cc741f80a87a4717af9051e18808a2cd',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'chore: bump follow-redirects in /folder-browser-plugin\n\nBumps [follow-redirects](https://github.com/follow-redirects/follow-redirects) from 1.10.0 to 1.15.2.\n- [Release notes](https://github.com/follow-redirects/follow-redirects/releases)\n- [Commits](https://github.com/follow-redirects/follow-redirects/compare/v1.10.0...v1.15.2)\n\n---\nupdated-dependencies:\n- dependency-name: follow-redirects\n  dependency-type: indirect\n...\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SAP/inquirer-gui/commits/458d3af8cc741f80a87a4717af9051e18808a2cd'}]},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z',
#   'org': {'id': 2531208,
#    'login': 'SAP',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SAP',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2531208?'}},
#  {'id': '28396254822',
#   'type': 'PushEvent',
#   'actor': {'id': 108680395,
#    'login': 'richardaeh',
#    'display_login': 'richardaeh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/richardaeh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108680395?'},
#   'repo': {'id': 510397814,
#    'name': 'richardaeh/richardaeh.github.io',
#    'url': 'https://api.github.com/repos/richardaeh/richardaeh.github.io'},
#   'payload': {'repository_id': 510397814,
#    'push_id': 13289076296,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e392513b9478fd983b46da5ec1c5bed98a9479e3',
#    'before': 'aa1e2d2287cf8c2a21c06c866f77a435c8498ea5',
#    'commits': [{'sha': 'e392513b9478fd983b46da5ec1c5bed98a9479e3',
#      'author': {'email': 'richardhoey@yahoo.co.uk', 'name': 'richardaeh'},
#      'message': 'Index update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/richardaeh/richardaeh.github.io/commits/e392513b9478fd983b46da5ec1c5bed98a9479e3'}]},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z'},
#  {'id': '28396254827',
#   'type': 'PushEvent',
#   'actor': {'id': 63110987,
#    'login': 'Anshika66-Gupta',
#    'display_login': 'Anshika66-Gupta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Anshika66-Gupta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63110987?'},
#   'repo': {'id': 625983325,
#    'name': 'Anshika66-Gupta/New-Booking-Application',
#    'url': 'https://api.github.com/repos/Anshika66-Gupta/New-Booking-Application'},
#   'payload': {'repository_id': 625983325,
#    'push_id': 13289076255,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e1be8134be05cb7551c622155fd0aeba7369453e',
#    'before': '08a7e429b4a91f129b8c1392e1eacd1c7a779949',
#    'commits': [{'sha': 'e1be8134be05cb7551c622155fd0aeba7369453e',
#      'author': {'email': 'ansgupta.01@gmail.com', 'name': '“Anshika'},
#      'message': 'admin done, movie route & controller token',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Anshika66-Gupta/New-Booking-Application/commits/e1be8134be05cb7551c622155fd0aeba7369453e'}]},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z'},
#  {'id': '28396254883',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 92680143,
#    'login': 'armru',
#    'display_login': 'armru',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/armru',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92680143?'},
#   'repo': {'id': 468311851,
#    'name': 'cloudnative-pg/cloudnative-pg',
#    'url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg'},
#   'payload': {'action': 'created',
#    'review': {'id': 1383591351,
#     'node_id': 'PRR_kwDOG-nfK85Sd-23',
#     'user': {'login': 'armru',
#      'id': 92680143,
#      'node_id': 'U_kgDOBYYvzw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/92680143?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/armru',
#      'html_url': 'https://github.com/armru',
#      'followers_url': 'https://api.github.com/users/armru/followers',
#      'following_url': 'https://api.github.com/users/armru/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/armru/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/armru/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/armru/subscriptions',
#      'organizations_url': 'https://api.github.com/users/armru/orgs',
#      'repos_url': 'https://api.github.com/users/armru/repos',
#      'events_url': 'https://api.github.com/users/armru/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/armru/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'commit_id': '0b90e15d991081e0b27781b6310d358b547f074a',
#     'submitted_at': '2023-04-13T14:43:01Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/cloudnative-pg/cloudnative-pg/pull/1919#pullrequestreview-1383591351',
#     'pull_request_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/1919',
#     'author_association': 'MEMBER',
#     '_links': {'html': {'href': 'https://github.com/cloudnative-pg/cloudnative-pg/pull/1919#pullrequestreview-1383591351'},
#      'pull_request': {'href': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/1919'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/1919',
#     'id': 1312214676,
#     'node_id': 'PR_kwDOG-nfK85ONs6U',
#     'html_url': 'https://github.com/cloudnative-pg/cloudnative-pg/pull/1919',
#     'diff_url': 'https://github.com/cloudnative-pg/cloudnative-pg/pull/1919.diff',
#     'patch_url': 'https://github.com/cloudnative-pg/cloudnative-pg/pull/1919.patch',
#     'issue_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues/1919',
#     'number': 1919,
#     'state': 'open',
#     'locked': False,
#     'title': 'fix: managed roles test should have non-expiring password',
#     'user': {'login': 'jsilvela',
#      'id': 423864,
#      'node_id': 'MDQ6VXNlcjQyMzg2NA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/423864?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jsilvela',
#      'html_url': 'https://github.com/jsilvela',
#      'followers_url': 'https://api.github.com/users/jsilvela/followers',
#      'following_url': 'https://api.github.com/users/jsilvela/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jsilvela/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jsilvela/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jsilvela/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jsilvela/orgs',
#      'repos_url': 'https://api.github.com/users/jsilvela/repos',
#      'events_url': 'https://api.github.com/users/jsilvela/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jsilvela/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'the E2E were failing because the fixture YAML had an expired password.\r\n\r\nSigned-off-by: Jaime Silvela <jaime.silvela@enterprisedb.com>',
#     'created_at': '2023-04-13T09:44:58Z',
#     'updated_at': '2023-04-13T14:43:02Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '2da2d5d7706587080f07587d7c97ecc9c8b73881',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'gbartolini',
#       'id': 182151,
#       'node_id': 'MDQ6VXNlcjE4MjE1MQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/182151?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gbartolini',
#       'html_url': 'https://github.com/gbartolini',
#       'followers_url': 'https://api.github.com/users/gbartolini/followers',
#       'following_url': 'https://api.github.com/users/gbartolini/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gbartolini/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gbartolini/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gbartolini/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gbartolini/orgs',
#       'repos_url': 'https://api.github.com/users/gbartolini/repos',
#       'events_url': 'https://api.github.com/users/gbartolini/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gbartolini/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'sxd',
#       'id': 908247,
#       'node_id': 'MDQ6VXNlcjkwODI0Nw==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/908247?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sxd',
#       'html_url': 'https://github.com/sxd',
#       'followers_url': 'https://api.github.com/users/sxd/followers',
#       'following_url': 'https://api.github.com/users/sxd/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sxd/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sxd/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sxd/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sxd/orgs',
#       'repos_url': 'https://api.github.com/users/sxd/repos',
#       'events_url': 'https://api.github.com/users/sxd/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sxd/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'leonardoce',
#       'id': 1572058,
#       'node_id': 'MDQ6VXNlcjE1NzIwNTg=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1572058?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/leonardoce',
#       'html_url': 'https://github.com/leonardoce',
#       'followers_url': 'https://api.github.com/users/leonardoce/followers',
#       'following_url': 'https://api.github.com/users/leonardoce/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/leonardoce/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/leonardoce/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/leonardoce/subscriptions',
#       'organizations_url': 'https://api.github.com/users/leonardoce/orgs',
#       'repos_url': 'https://api.github.com/users/leonardoce/repos',
#       'events_url': 'https://api.github.com/users/leonardoce/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/leonardoce/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'phisco',
#       'id': 5697904,
#       'node_id': 'MDQ6VXNlcjU2OTc5MDQ=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5697904?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/phisco',
#       'html_url': 'https://github.com/phisco',
#       'followers_url': 'https://api.github.com/users/phisco/followers',
#       'following_url': 'https://api.github.com/users/phisco/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/phisco/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/phisco/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/phisco/subscriptions',
#       'organizations_url': 'https://api.github.com/users/phisco/orgs',
#       'repos_url': 'https://api.github.com/users/phisco/repos',
#       'events_url': 'https://api.github.com/users/phisco/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/phisco/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'fcanovai',
#       'id': 6904870,
#       'node_id': 'MDQ6VXNlcjY5MDQ4NzA=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6904870?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/fcanovai',
#       'html_url': 'https://github.com/fcanovai',
#       'followers_url': 'https://api.github.com/users/fcanovai/followers',
#       'following_url': 'https://api.github.com/users/fcanovai/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/fcanovai/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/fcanovai/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/fcanovai/subscriptions',
#       'organizations_url': 'https://api.github.com/users/fcanovai/orgs',
#       'repos_url': 'https://api.github.com/users/fcanovai/repos',
#       'events_url': 'https://api.github.com/users/fcanovai/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/fcanovai/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [{'id': 4060041639,
#       'node_id': 'LA_kwDOG-nfK87x_1Gn',
#       'url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/labels/ok%20to%20merge%20:ok_hand:',
#       'name': 'ok to merge :ok_hand:',
#       'color': 'C2E0C6',
#       'default': False,
#       'description': 'This PR can be merged'},
#      {'id': 4166048581,
#       'node_id': 'LA_kwDOG-nfK874UNtF',
#       'url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/labels/no-issue',
#       'name': 'no-issue',
#       'color': '071531',
#       'default': False,
#       'description': ''}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/1919/commits',
#     'review_comments_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/1919/comments',
#     'review_comment_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues/1919/comments',
#     'statuses_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/statuses/0b90e15d991081e0b27781b6310d358b547f074a',
#     'head': {'label': 'cloudnative-pg:dev/fix-managed-roles-fixture',
#      'ref': 'dev/fix-managed-roles-fixture',
#      'sha': '0b90e15d991081e0b27781b6310d358b547f074a',
#      'user': {'login': 'cloudnative-pg',
#       'id': 100373852,
#       'node_id': 'O_kgDOBfuVXA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/100373852?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cloudnative-pg',
#       'html_url': 'https://github.com/cloudnative-pg',
#       'followers_url': 'https://api.github.com/users/cloudnative-pg/followers',
#       'following_url': 'https://api.github.com/users/cloudnative-pg/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cloudnative-pg/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cloudnative-pg/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cloudnative-pg/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cloudnative-pg/orgs',
#       'repos_url': 'https://api.github.com/users/cloudnative-pg/repos',
#       'events_url': 'https://api.github.com/users/cloudnative-pg/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cloudnative-pg/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 468311851,
#       'node_id': 'R_kgDOG-nfKw',
#       'name': 'cloudnative-pg',
#       'full_name': 'cloudnative-pg/cloudnative-pg',
#       'private': False,
#       'owner': {'login': 'cloudnative-pg',
#        'id': 100373852,
#        'node_id': 'O_kgDOBfuVXA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/100373852?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cloudnative-pg',
#        'html_url': 'https://github.com/cloudnative-pg',
#        'followers_url': 'https://api.github.com/users/cloudnative-pg/followers',
#        'following_url': 'https://api.github.com/users/cloudnative-pg/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cloudnative-pg/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cloudnative-pg/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cloudnative-pg/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cloudnative-pg/orgs',
#        'repos_url': 'https://api.github.com/users/cloudnative-pg/repos',
#        'events_url': 'https://api.github.com/users/cloudnative-pg/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cloudnative-pg/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/cloudnative-pg/cloudnative-pg',
#       'description': 'CloudNativePG is a Kubernetes operator that covers the full lifecycle of a PostgreSQL database cluster with a primary/standby architecture, using native streaming replication',
#       'fork': False,
#       'url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg',
#       'forks_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/forks',
#       'keys_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/teams',
#       'hooks_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/events',
#       'assignees_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/tags',
#       'blobs_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/languages',
#       'stargazers_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/subscription',
#       'commits_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/merges',
#       'archive_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/downloads',
#       'issues_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/deployments',
#       'created_at': '2022-03-10T11:21:32Z',
#       'updated_at': '2023-04-13T14:23:18Z',
#       'pushed_at': '2023-04-13T09:58:47Z',
#       'git_url': 'git://github.com/cloudnative-pg/cloudnative-pg.git',
#       'ssh_url': 'git@github.com:cloudnative-pg/cloudnative-pg.git',
#       'clone_url': 'https://github.com/cloudnative-pg/cloudnative-pg.git',
#       'svn_url': 'https://github.com/cloudnative-pg/cloudnative-pg',
#       'homepage': 'https://cloudnative-pg.io',
#       'size': 16930,
#       'stargazers_count': 1148,
#       'watchers_count': 1148,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 89,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 76,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': True,
#       'topics': ['automated-failover',
#        'business-continuity',
#        'database',
#        'database-management',
#        'devops',
#        'disaster-recovery',
#        'failover',
#        'high-availability',
#        'json-logging',
#        'k8s',
#        'kubectl-plugin',
#        'kubernetes',
#        'operator',
#        'postgres',
#        'postgresql',
#        'prometheus-exporter',
#        'replication',
#        'self-healing',
#        'sql',
#        'switchover'],
#       'visibility': 'public',
#       'forks': 89,
#       'open_issues': 76,
#       'watchers': 1148,
#       'default_branch': 'main'}},
#     'base': {'label': 'cloudnative-pg:main',
#      'ref': 'main',
#      'sha': '4df08a85f91b4ccf8e61027de7c5ae5c658f0d1d',
#      'user': {'login': 'cloudnative-pg',
#       'id': 100373852,
#       'node_id': 'O_kgDOBfuVXA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/100373852?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cloudnative-pg',
#       'html_url': 'https://github.com/cloudnative-pg',
#       'followers_url': 'https://api.github.com/users/cloudnative-pg/followers',
#       'following_url': 'https://api.github.com/users/cloudnative-pg/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cloudnative-pg/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cloudnative-pg/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cloudnative-pg/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cloudnative-pg/orgs',
#       'repos_url': 'https://api.github.com/users/cloudnative-pg/repos',
#       'events_url': 'https://api.github.com/users/cloudnative-pg/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cloudnative-pg/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 468311851,
#       'node_id': 'R_kgDOG-nfKw',
#       'name': 'cloudnative-pg',
#       'full_name': 'cloudnative-pg/cloudnative-pg',
#       'private': False,
#       'owner': {'login': 'cloudnative-pg',
#        'id': 100373852,
#        'node_id': 'O_kgDOBfuVXA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/100373852?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cloudnative-pg',
#        'html_url': 'https://github.com/cloudnative-pg',
#        'followers_url': 'https://api.github.com/users/cloudnative-pg/followers',
#        'following_url': 'https://api.github.com/users/cloudnative-pg/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cloudnative-pg/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cloudnative-pg/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cloudnative-pg/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cloudnative-pg/orgs',
#        'repos_url': 'https://api.github.com/users/cloudnative-pg/repos',
#        'events_url': 'https://api.github.com/users/cloudnative-pg/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cloudnative-pg/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/cloudnative-pg/cloudnative-pg',
#       'description': 'CloudNativePG is a Kubernetes operator that covers the full lifecycle of a PostgreSQL database cluster with a primary/standby architecture, using native streaming replication',
#       'fork': False,
#       'url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg',
#       'forks_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/forks',
#       'keys_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/teams',
#       'hooks_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/events',
#       'assignees_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/tags',
#       'blobs_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/languages',
#       'stargazers_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/subscription',
#       'commits_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/merges',
#       'archive_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/downloads',
#       'issues_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/deployments',
#       'created_at': '2022-03-10T11:21:32Z',
#       'updated_at': '2023-04-13T14:23:18Z',
#       'pushed_at': '2023-04-13T09:58:47Z',
#       'git_url': 'git://github.com/cloudnative-pg/cloudnative-pg.git',
#       'ssh_url': 'git@github.com:cloudnative-pg/cloudnative-pg.git',
#       'clone_url': 'https://github.com/cloudnative-pg/cloudnative-pg.git',
#       'svn_url': 'https://github.com/cloudnative-pg/cloudnative-pg',
#       'homepage': 'https://cloudnative-pg.io',
#       'size': 16930,
#       'stargazers_count': 1148,
#       'watchers_count': 1148,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 89,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 76,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': True,
#       'topics': ['automated-failover',
#        'business-continuity',
#        'database',
#        'database-management',
#        'devops',
#        'disaster-recovery',
#        'failover',
#        'high-availability',
#        'json-logging',
#        'k8s',
#        'kubectl-plugin',
#        'kubernetes',
#        'operator',
#        'postgres',
#        'postgresql',
#        'prometheus-exporter',
#        'replication',
#        'self-healing',
#        'sql',
#        'switchover'],
#       'visibility': 'public',
#       'forks': 89,
#       'open_issues': 76,
#       'watchers': 1148,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/1919'},
#      'html': {'href': 'https://github.com/cloudnative-pg/cloudnative-pg/pull/1919'},
#      'issue': {'href': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues/1919'},
#      'comments': {'href': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/issues/1919/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/1919/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/pulls/1919/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/cloudnative-pg/cloudnative-pg/statuses/0b90e15d991081e0b27781b6310d358b547f074a'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z',
#   'org': {'id': 100373852,
#    'login': 'cloudnative-pg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudnative-pg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100373852?'}},
#  {'id': '28396254809',
#   'type': 'PushEvent',
#   'actor': {'id': 5972917,
#    'login': 'Kielek',
#    'display_login': 'Kielek',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kielek',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5972917?'},
#   'repo': {'id': 279725748,
#    'name': 'open-telemetry/opentelemetry-dotnet-instrumentation',
#    'url': 'https://api.github.com/repos/open-telemetry/opentelemetry-dotnet-instrumentation'},
#   'payload': {'repository_id': 279725748,
#    'push_id': 13289076268,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2b94a30d0c5d3a6268579bda270a5018f48821a3',
#    'before': '8595c807943509ee53210f42ea162a80e62d59a6',
#    'commits': [{'sha': '2b94a30d0c5d3a6268579bda270a5018f48821a3',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump System.IO.Abstractions from 19.2.9 to 19.2.11 (#2450)\n\nBumps [System.IO.Abstractions](https://github.com/TestableIO/System.IO.Abstractions) from 19.2.9 to 19.2.11.\r\n- [Release notes](https://github.com/TestableIO/System.IO.Abstractions/releases)\r\n- [Commits](https://github.com/TestableIO/System.IO.Abstractions/compare/v19.2.9...v19.2.11)\r\n\r\n---\r\nupdated-dependencies:\r\n- dependency-name: System.IO.Abstractions\r\n  dependency-type: direct:production\r\n  update-type: version-update:semver-patch\r\n...\r\n\r\nSigned-off-by: dependabot[bot] <support@github.com>\r\nCo-authored-by: dependabot[bot] <49699333+dependabot[bot]@users.noreply.github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/open-telemetry/opentelemetry-dotnet-instrumentation/commits/2b94a30d0c5d3a6268579bda270a5018f48821a3'}]},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z',
#   'org': {'id': 49998002,
#    'login': 'open-telemetry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/open-telemetry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49998002?'}},
#  {'id': '28396254863',
#   'type': 'PushEvent',
#   'actor': {'id': 7548711,
#    'login': 'cardigliano',
#    'display_login': 'cardigliano',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cardigliano',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7548711?'},
#   'repo': {'id': 34847907,
#    'name': 'ntop/ntopng',
#    'url': 'https://api.github.com/repos/ntop/ntopng'},
#   'payload': {'repository_id': 34847907,
#    'push_id': 13289076328,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'c3e1729e2cec05f59886fd97514f9d6775df2910',
#    'before': 'b2d0e341c592ba36f2acb480d3279eef79d6736e',
#    'commits': [{'sha': 'c3e1729e2cec05f59886fd97514f9d6775df2910',
#      'author': {'email': 'cardigliano@ntop.org',
#       'name': 'Alfredo Cardigliano'},
#      'message': 'Add disk2disk support in ntopctl',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ntop/ntopng/commits/c3e1729e2cec05f59886fd97514f9d6775df2910'}]},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z',
#   'org': {'id': 12014789,
#    'login': 'ntop',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ntop',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12014789?'}},
#  {'id': '28396254820',
#   'type': 'PushEvent',
#   'actor': {'id': 116730455,
#    'login': 'vntuananhbui',
#    'display_login': 'vntuananhbui',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vntuananhbui',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/116730455?'},
#   'repo': {'id': 625628494,
#    'name': 'vntuananhbui/Infiniture-BookStore-Website',
#    'url': 'https://api.github.com/repos/vntuananhbui/Infiniture-BookStore-Website'},
#   'payload': {'repository_id': 625628494,
#    'push_id': 13289076321,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '23dc8fb070b5914011e73e1d50910f41447a8cc5',
#    'before': '57fb3a52c84fcc1115e6bd970c1d49acee1fd414',
#    'commits': [{'sha': '23dc8fb070b5914011e73e1d50910f41447a8cc5',
#      'author': {'email': '116730455+vntuananhbui@users.noreply.github.com',
#       'name': 'vntuananh'},
#      'message': 'change drop down location',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vntuananhbui/Infiniture-BookStore-Website/commits/23dc8fb070b5914011e73e1d50910f41447a8cc5'}]},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z'},
#  {'id': '28396254780',
#   'type': 'PushEvent',
#   'actor': {'id': 109960975,
#    'login': 'hwright-os',
#    'display_login': 'hwright-os',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hwright-os',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/109960975?'},
#   'repo': {'id': 34907883,
#    'name': 'OrdnanceSurvey/OS-OpenMap-Local-stylesheets',
#    'url': 'https://api.github.com/repos/OrdnanceSurvey/OS-OpenMap-Local-stylesheets'},
#   'payload': {'repository_id': 34907883,
#    'push_id': 13289076282,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'af7c1a3a7f7751f65c033c255df8b9865c3bded6',
#    'before': '2ffa3357aecd8b8a1cf7e2c668b9f8fad0a88498',
#    'commits': [{'sha': 'af7c1a3a7f7751f65c033c255df8b9865c3bded6',
#      'author': {'email': '109960975+hwright-os@users.noreply.github.com',
#       'name': 'hwright-os'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OrdnanceSurvey/OS-OpenMap-Local-stylesheets/commits/af7c1a3a7f7751f65c033c255df8b9865c3bded6'}]},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z',
#   'org': {'id': 2436924,
#    'login': 'OrdnanceSurvey',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OrdnanceSurvey',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2436924?'}},
#  {'id': '28396254806',
#   'type': 'CreateEvent',
#   'actor': {'id': 113639795,
#    'login': 'Dutra-Pedro',
#    'display_login': 'Dutra-Pedro',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dutra-Pedro',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/113639795?'},
#   'repo': {'id': 627475861,
#    'name': 'Dutra-Pedro/TextArea',
#    'url': 'https://api.github.com/repos/Dutra-Pedro/TextArea'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z'},
#  {'id': '28396254782',
#   'type': 'IssuesEvent',
#   'actor': {'id': 59863112,
#    'login': 'Nter-developer',
#    'display_login': 'Nter-developer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nter-developer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59863112?'},
#   'repo': {'id': 618336874,
#    'name': 'Nter-developer/bravo-HealthPark-BE',
#    'url': 'https://api.github.com/repos/Nter-developer/bravo-HealthPark-BE'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/Nter-developer/bravo-HealthPark-BE/issues/6',
#     'repository_url': 'https://api.github.com/repos/Nter-developer/bravo-HealthPark-BE',
#     'labels_url': 'https://api.github.com/repos/Nter-developer/bravo-HealthPark-BE/issues/6/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Nter-developer/bravo-HealthPark-BE/issues/6/comments',
#     'events_url': 'https://api.github.com/repos/Nter-developer/bravo-HealthPark-BE/issues/6/events',
#     'html_url': 'https://github.com/Nter-developer/bravo-HealthPark-BE/issues/6',
#     'id': 1640909725,
#     'node_id': 'I_kwDOJNsSas5hzkud',
#     'number': 6,
#     'title': '처방약,영양제 객체 생성 구현한다.',
#     'user': {'login': 'kangjjs',
#      'id': 94667600,
#      'node_id': 'U_kgDOBaSDUA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/94667600?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kangjjs',
#      'html_url': 'https://github.com/kangjjs',
#      'followers_url': 'https://api.github.com/users/kangjjs/followers',
#      'following_url': 'https://api.github.com/users/kangjjs/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kangjjs/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kangjjs/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kangjjs/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kangjjs/orgs',
#      'repos_url': 'https://api.github.com/users/kangjjs/repos',
#      'events_url': 'https://api.github.com/users/kangjjs/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kangjjs/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 5324586696,
#       'node_id': 'LA_kwDOJNsSas8AAAABPV6-yA',
#       'url': 'https://api.github.com/repos/Nter-developer/bravo-HealthPark-BE/labels/feature',
#       'name': 'feature',
#       'color': 'BFD4F2',
#       'default': False,
#       'description': 'function implementation'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2023-03-26T13:24:52Z',
#     'updated_at': '2023-04-13T14:43:01Z',
#     'closed_at': '2023-04-13T14:43:01Z',
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'body': '## 🤷목적\r\n*  MedicatioInfo를 통해서 복약 정보를 저장한다.\r\n*  MedicatioInfo의 정보등을 통해서 복약정보들을 받아온다. \r\n## 🔨상세 작업 내용\r\n- [ ] MedicationInfo.java\r\n- [ ] MedicationInfoController.java\r\n- [ ] MedicationInfoService.java\r\n- [ ] MedicationInfoRepository.java\r\n- [ ] MedicationInfoDto.java\r\n- [ ] MedicationInfoForm.java\r\n## 📝참고 사항\r\n> 컨트롤러에서 userId 받아서 하는건 전부 login한다음에 세션값 받게 바꾸면 다 세션 아이디 받는거로 바꿀\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/Nter-developer/bravo-HealthPark-BE/issues/6/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/Nter-developer/bravo-HealthPark-BE/issues/6/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'completed'}},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z'},
#  {'id': '28396254730',
#   'type': 'DeleteEvent',
#   'actor': {'id': 112381491,
#    'login': 'piasooriy',
#    'display_login': 'piasooriy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/piasooriy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112381491?'},
#   'repo': {'id': 615735067,
#    'name': 'piasooriy/pias-bookstore',
#    'url': 'https://api.github.com/repos/piasooriy/pias-bookstore'},
#   'payload': {'ref': 'Feature/meeting-notes-13/04/23',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z'},
#  {'id': '28396254789',
#   'type': 'PushEvent',
#   'actor': {'id': 63140278,
#    'login': 'kenshgy',
#    'display_login': 'kenshgy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kenshgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63140278?'},
#   'repo': {'id': 622992916,
#    'name': 'kenshgy/happy-wedding',
#    'url': 'https://api.github.com/repos/kenshgy/happy-wedding'},
#   'payload': {'repository_id': 622992916,
#    'push_id': 13289076280,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '4bad5d25a24ee241e0a9fdef02d67b2e9b39fa13',
#    'before': 'd4485b3af2aeed3a6b31c92031e387c7f3a099de',
#    'commits': [{'sha': '19b81cdc19773e3115221423772138f5b9dd7fbd',
#      'author': {'email': 'ken.shgy.1386@gmail.com', 'name': 'kenshgy'},
#      'message': 'upd',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kenshgy/happy-wedding/commits/19b81cdc19773e3115221423772138f5b9dd7fbd'},
#     {'sha': '4bad5d25a24ee241e0a9fdef02d67b2e9b39fa13',
#      'author': {'email': 'ken.shgy.1386@gmail.com', 'name': 'kenshgy'},
#      'message': 'upd',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kenshgy/happy-wedding/commits/4bad5d25a24ee241e0a9fdef02d67b2e9b39fa13'}]},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z'},
#  {'id': '28396254745',
#   'type': 'PushEvent',
#   'actor': {'id': 68828345,
#    'login': 'antikkorps',
#    'display_login': 'antikkorps',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/antikkorps',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68828345?'},
#   'repo': {'id': 626972501,
#    'name': 'antikkorps/globalAppV3',
#    'url': 'https://api.github.com/repos/antikkorps/globalAppV3'},
#   'payload': {'repository_id': 626972501,
#    'push_id': 13289076254,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/calendar_functionnality',
#    'head': '9313e87fd0ac0f1cb3fc030ef278837a0f00066e',
#    'before': 'b3bfdae592c5ac7a1e4e8e4d0509f3b56b2d3e27',
#    'commits': [{'sha': '9313e87fd0ac0f1cb3fc030ef278837a0f00066e',
#      'author': {'email': 'franckvienot7@gmail.com', 'name': 'antikkorps'},
#      'message': 'added a booking calendar',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/antikkorps/globalAppV3/commits/9313e87fd0ac0f1cb3fc030ef278837a0f00066e'}]},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z'},
#  {'id': '28396254749',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 2636487,
#    'login': 'mteu',
#    'display_login': 'mteu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mteu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2636487?'},
#   'repo': {'id': 624145610,
#    'name': 'shrugify/yolo',
#    'url': 'https://api.github.com/repos/shrugify/yolo'},
#   'payload': {'action': 'opened',
#    'number': 20,
#    'pull_request': {'url': 'https://api.github.com/repos/shrugify/yolo/pulls/20',
#     'id': 1312643859,
#     'node_id': 'PR_kwDOJTO0ys5OPVsT',
#     'html_url': 'https://github.com/shrugify/yolo/pull/20',
#     'diff_url': 'https://github.com/shrugify/yolo/pull/20.diff',
#     'patch_url': 'https://github.com/shrugify/yolo/pull/20.patch',
#     'issue_url': 'https://api.github.com/repos/shrugify/yolo/issues/20',
#     'number': 20,
#     'state': 'open',
#     'locked': False,
#     'title': '[TASK] Smoothen the animation based on command length',
#     'user': {'login': 'mteu',
#      'id': 2636487,
# ...
#       'starred_url': 'https://api.github.com/users/pimcore/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/pimcore/subscriptions',
#       'organizations_url': 'https://api.github.com/users/pimcore/orgs',
#       'repos_url': 'https://api.github.com/users/pimcore/repos',
#       'events_url': 'https://api.github.com/users/pimcore/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/pimcore/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 620293025,
#       'node_id': 'R_kgDOJPjroQ',
#       'name': 'file-explorer-bundle',
#       'full_name': 'pimcore/file-explorer-bundle',
#       'private': False,
#       'owner': {'login': 'pimcore',
#        'id': 686745,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY4Njc0NQ==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/686745?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/pimcore',
#        'html_url': 'https://github.com/pimcore',
#        'followers_url': 'https://api.github.com/users/pimcore/followers',
#        'following_url': 'https://api.github.com/users/pimcore/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/pimcore/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/pimcore/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/pimcore/subscriptions',
#        'organizations_url': 'https://api.github.com/users/pimcore/orgs',
#        'repos_url': 'https://api.github.com/users/pimcore/repos',
#        'events_url': 'https://api.github.com/users/pimcore/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/pimcore/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/pimcore/file-explorer-bundle',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/pimcore/file-explorer-bundle',
#       'forks_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/forks',
#       'keys_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/teams',
#       'hooks_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/hooks',
#       'issue_events_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/events',
#       'assignees_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/tags',
#       'blobs_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/languages',
#       'stargazers_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/stargazers',
#       'contributors_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/contributors',
#       'subscribers_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/subscribers',
#       'subscription_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/subscription',
#       'commits_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/merges',
#       'archive_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/downloads',
#       'issues_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/deployments',
#       'created_at': '2023-03-28T12:01:46Z',
#       'updated_at': '2023-04-04T21:16:52Z',
#       'pushed_at': '2023-04-13T14:42:21Z',
#       'git_url': 'git://github.com/pimcore/file-explorer-bundle.git',
#       'ssh_url': 'git@github.com:pimcore/file-explorer-bundle.git',
#       'clone_url': 'https://github.com/pimcore/file-explorer-bundle.git',
#       'svn_url': 'https://github.com/pimcore/file-explorer-bundle',
#       'homepage': None,
#       'size': 75,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 5,
#       'watchers': 1,
#       'default_branch': '1.x'}},
#     'base': {'label': 'pimcore:1.x',
#      'ref': '1.x',
#      'sha': 'd12fa6d1b5bacb75d16b59468b3d78b288756a89',
#      'user': {'login': 'pimcore',
#       'id': 686745,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY4Njc0NQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/686745?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/pimcore',
#       'html_url': 'https://github.com/pimcore',
#       'followers_url': 'https://api.github.com/users/pimcore/followers',
#       'following_url': 'https://api.github.com/users/pimcore/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/pimcore/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/pimcore/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/pimcore/subscriptions',
#       'organizations_url': 'https://api.github.com/users/pimcore/orgs',
#       'repos_url': 'https://api.github.com/users/pimcore/repos',
#       'events_url': 'https://api.github.com/users/pimcore/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/pimcore/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 620293025,
#       'node_id': 'R_kgDOJPjroQ',
#       'name': 'file-explorer-bundle',
#       'full_name': 'pimcore/file-explorer-bundle',
#       'private': False,
#       'owner': {'login': 'pimcore',
#        'id': 686745,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY4Njc0NQ==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/686745?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/pimcore',
#        'html_url': 'https://github.com/pimcore',
#        'followers_url': 'https://api.github.com/users/pimcore/followers',
#        'following_url': 'https://api.github.com/users/pimcore/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/pimcore/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/pimcore/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/pimcore/subscriptions',
#        'organizations_url': 'https://api.github.com/users/pimcore/orgs',
#        'repos_url': 'https://api.github.com/users/pimcore/repos',
#        'events_url': 'https://api.github.com/users/pimcore/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/pimcore/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/pimcore/file-explorer-bundle',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/pimcore/file-explorer-bundle',
#       'forks_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/forks',
#       'keys_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/teams',
#       'hooks_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/hooks',
#       'issue_events_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/events',
#       'assignees_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/tags',
#       'blobs_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/languages',
#       'stargazers_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/stargazers',
#       'contributors_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/contributors',
#       'subscribers_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/subscribers',
#       'subscription_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/subscription',
#       'commits_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/merges',
#       'archive_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/downloads',
#       'issues_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/pimcore/file-explorer-bundle/deployments',
#       'created_at': '2023-03-28T12:01:46Z',
#       'updated_at': '2023-04-04T21:16:52Z',
#       'pushed_at': '2023-04-13T14:42:21Z',
#       'git_url': 'git://github.com/pimcore/file-explorer-bundle.git',
#       'ssh_url': 'git@github.com:pimcore/file-explorer-bundle.git',
#       'clone_url': 'https://github.com/pimcore/file-explorer-bundle.git',
#       'svn_url': 'https://github.com/pimcore/file-explorer-bundle',
#       'homepage': None,
#       'size': 75,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 5,
#       'watchers': 1,
#       'default_branch': '1.x'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/pimcore/file-explorer-bundle/pulls/8'},
#      'html': {'href': 'https://github.com/pimcore/file-explorer-bundle/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/pimcore/file-explorer-bundle/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/pimcore/file-explorer-bundle/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/pimcore/file-explorer-bundle/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/pimcore/file-explorer-bundle/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/pimcore/file-explorer-bundle/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/pimcore/file-explorer-bundle/statuses/60fb349172f56d2ee5a62274bea5ff20596199d9'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z',
#   'org': {'id': 686745,
#    'login': 'pimcore',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pimcore',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/686745?'}},
#  {'id': '28396254641',
#   'type': 'CreateEvent',
#   'actor': {'id': 4303697,
#    'login': 'Iaincox',
#    'display_login': 'Iaincox',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Iaincox',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4303697?'},
#   'repo': {'id': 627475857,
#    'name': 'Iaincox/Shore.Fund',
#    'url': 'https://api.github.com/repos/Iaincox/Shore.Fund'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-13T14:43:02Z'}]

# %%
# How many events are we looking at?
len(github_response)
# Out:
# 30

# %%
# What are the keys in the first event?
github_response[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at', 'org'])

# %%
# We can see that 'repo' is another subdictionary.
# What are the keys in the 'repo' subdictionary?
github_response[0]['repo'].keys()
# Out:
# dict_keys(['id', 'name', 'url'])

# %%
# What's the value for the key 'name' in 'repo'?
github_response[0]['repo']['name']
# Out:
# 'SAP/inquirer-gui'

# %% [markdown]
# #### Transforming a JSON into a DataFrame

# %% [markdown]
# ##### Option 1: pd.DataFrame()

# %%
# Turn it into a pandas DataFrame.
pd.DataFrame(github_response)
# Out:
#              id                           type  \
# 0   28396254892                      PushEvent
# 1   28396254822                      PushEvent
# 2   28396254827                      PushEvent
# 3   28396254883         PullRequestReviewEvent
# 4   28396254809                      PushEvent
# 5   28396254863                      PushEvent
# 6   28396254820                      PushEvent
# 7   28396254780                      PushEvent
# 8   28396254806                    CreateEvent
# 9   28396254782                    IssuesEvent
# 10  28396254730                    DeleteEvent
# 11  28396254789                      PushEvent
# 12  28396254745                      PushEvent
# 13  28396254749               PullRequestEvent
# 14  28396254756  PullRequestReviewCommentEvent
# 15  28396254719                      PushEvent
# 16  28396254773               PullRequestEvent
# 17  28396254617                      PushEvent
# 18  28396254757               PullRequestEvent
# 19  28396254727                    DeleteEvent
# 20  28396254704                     WatchEvent
# 21  28396254612                    PublicEvent
# 22  28396254629                    CreateEvent
# 23  28396254717                      PushEvent
# 24  28396254644                      PushEvent
# 25  28396254645                      PushEvent
# 26  28396254702                      PushEvent
# 27  28396254712                    CreateEvent
# 28  28396254684         PullRequestReviewEvent
# 29  28396254641                    CreateEvent
#
#                                                 actor  \
# 0   {'id': 49699333, 'login': 'dependabot[bot]', '...
# 1   {'id': 108680395, 'login': 'richardaeh', 'disp...
# 2   {'id': 63110987, 'login': 'Anshika66-Gupta', '...
# 3   {'id': 92680143, 'login': 'armru', 'display_lo...
# 4   {'id': 5972917, 'login': 'Kielek', 'display_lo...
# 5   {'id': 7548711, 'login': 'cardigliano', 'displ...
# 6   {'id': 116730455, 'login': 'vntuananhbui', 'di...
# 7   {'id': 109960975, 'login': 'hwright-os', 'disp...
# 8   {'id': 113639795, 'login': 'Dutra-Pedro', 'dis...
# 9   {'id': 59863112, 'login': 'Nter-developer', 'd...
# 10  {'id': 112381491, 'login': 'piasooriy', 'displ...
# 11  {'id': 63140278, 'login': 'kenshgy', 'display_...
# 12  {'id': 68828345, 'login': 'antikkorps', 'displ...
# 13  {'id': 2636487, 'login': 'mteu', 'display_logi...
# 14  {'id': 97134765, 'login': 'aryaantony92', 'dis...
# 15  {'id': 107903342, 'login': 'YUSUNOK', 'display...
# 16  {'id': 10810283, 'login': 'direwolf-github', '...
# 17  {'id': 4802196, 'login': 'cerminar', 'display_...
# 18  {'id': 101598059, 'login': 'brandao-rafael', '...
# 19  {'id': 348030, 'login': 'DuttonMa', 'display_l...
# 20  {'id': 5344654, 'login': 'yun900800', 'display...
# 21  {'id': 107007336, 'login': 'Ben11029', 'displa...
# 22  {'id': 10810283, 'login': 'direwolf-github', '...
# 23  {'id': 118745830, 'login': 'Archeozyx', 'displ...
# 24  {'id': 56254275, 'login': 'astarte-machine', '...
# 25  {'id': 76970935, 'login': 'xiaoandy1974', 'dis...
# 26  {'id': 77192131, 'login': 'rhd5656', 'display_...
# 27  {'id': 43047562, 'login': 'scala-steward', 'di...
# 28  {'id': 97134765, 'login': 'aryaantony92', 'dis...
# 29  {'id': 4303697, 'login': 'Iaincox', 'display_l...
#
#                                                  repo  \
# 0   {'id': 235323015, 'name': 'SAP/inquirer-gui', ...
# 1   {'id': 510397814, 'name': 'richardaeh/richarda...
# 2   {'id': 625983325, 'name': 'Anshika66-Gupta/New...
# 3   {'id': 468311851, 'name': 'cloudnative-pg/clou...
# 4   {'id': 279725748, 'name': 'open-telemetry/open...
# 5   {'id': 34847907, 'name': 'ntop/ntopng', 'url':...
# 6   {'id': 625628494, 'name': 'vntuananhbui/Infini...
# 7   {'id': 34907883, 'name': 'OrdnanceSurvey/OS-Op...
# 8   {'id': 627475861, 'name': 'Dutra-Pedro/TextAre...
# 9   {'id': 618336874, 'name': 'Nter-developer/brav...
# 10  {'id': 615735067, 'name': 'piasooriy/pias-book...
# 11  {'id': 622992916, 'name': 'kenshgy/happy-weddi...
# 12  {'id': 626972501, 'name': 'antikkorps/globalAp...
# 13  {'id': 624145610, 'name': 'shrugify/yolo', 'ur...
# 14  {'id': 620293025, 'name': 'pimcore/file-explor...
# 15  {'id': 626565771, 'name': 'YUSUNOK/algorithm',...
# 16  {'id': 627475790, 'name': 'direwolf-github/eph...
# 17  {'id': 10995912, 'name': 'cerminar/cmssw', 'ur...
# 18  {'id': 626498827, 'name': 'brandao-rafael/Aidi...
# 19  {'id': 255885934, 'name': 'dof-dss/nicsdru_uni...
# 20  {'id': 116549714, 'name': 'azarus/angular-drag...
# 21  {'id': 627442817, 'name': 'Ben11029/chuangba',...
# 22  {'id': 627475790, 'name': 'direwolf-github/eph...
# 23  {'id': 623025203, 'name': 'StephanoNK/ASD-TR',...
# 24  {'id': 105633950, 'name': 'astarte-platform/do...
# 25  {'id': 326797979, 'name': 'xiaoandy1974/test',...
# 26  {'id': 620232877, 'name': 'NK590/1Day1ProblemC...
# 27  {'id': 196458879, 'name': 'scala-steward/fs2-k...
# 28  {'id': 620293025, 'name': 'pimcore/file-explor...
# 29  {'id': 627475857, 'name': 'Iaincox/Shore.Fund'...
#
#                                               payload  public  \
# 0   {'repository_id': 235323015, 'push_id': 132890...    True
# 1   {'repository_id': 510397814, 'push_id': 132890...    True
# 2   {'repository_id': 625983325, 'push_id': 132890...    True
# 3   {'action': 'created', 'review': {'id': 1383591...    True
# 4   {'repository_id': 279725748, 'push_id': 132890...    True
# 5   {'repository_id': 34847907, 'push_id': 1328907...    True
# 6   {'repository_id': 625628494, 'push_id': 132890...    True
# 7   {'repository_id': 34907883, 'push_id': 1328907...    True
# 8   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 9   {'action': 'closed', 'issue': {'url': 'https:/...    True
# 10  {'ref': 'Feature/meeting-notes-13/04/23', 'ref...    True
# 11  {'repository_id': 622992916, 'push_id': 132890...    True
# 12  {'repository_id': 626972501, 'push_id': 132890...    True
# 13  {'action': 'opened', 'number': 20, 'pull_reque...    True
# 14  {'action': 'created', 'comment': {'url': 'http...    True
# 15  {'repository_id': 626565771, 'push_id': 132890...    True
# 16  {'action': 'opened', 'number': 1, 'pull_reques...    True
# 17  {'repository_id': 10995912, 'push_id': 1328907...    True
# 18  {'action': 'opened', 'number': 13, 'pull_reque...    True
# 19  {'ref': 'D8UN-875-c', 'ref_type': 'branch', 'p...    True
# 20                              {'action': 'started'}    True
# 21                                                 {}    True
# 22  {'ref': 'branch-7edb7a3e', 'ref_type': 'branch...    True
# 23  {'repository_id': 623025203, 'push_id': 132890...    True
# 24  {'repository_id': 105633950, 'push_id': 132890...    True
# 25  {'repository_id': 326797979, 'push_id': 132890...    True
# 26  {'repository_id': 620232877, 'push_id': 132890...    True
# 27  {'ref': 'update/series/2.x/kafka-avro-serializ...    True
# 28  {'action': 'created', 'review': {'id': 1383591...    True
# 29  {'ref': None, 'ref_type': 'repository', 'maste...    True
#
#               created_at                                                org
# 0   2023-04-13T14:43:02Z  {'id': 2531208, 'login': 'SAP', 'gravatar_id':...
# 1   2023-04-13T14:43:02Z                                                NaN
# 2   2023-04-13T14:43:02Z                                                NaN
# 3   2023-04-13T14:43:02Z  {'id': 100373852, 'login': 'cloudnative-pg', '...
# 4   2023-04-13T14:43:02Z  {'id': 49998002, 'login': 'open-telemetry', 'g...
# 5   2023-04-13T14:43:02Z  {'id': 12014789, 'login': 'ntop', 'gravatar_id...
# 6   2023-04-13T14:43:02Z                                                NaN
# 7   2023-04-13T14:43:02Z  {'id': 2436924, 'login': 'OrdnanceSurvey', 'gr...
# 8   2023-04-13T14:43:02Z                                                NaN
# 9   2023-04-13T14:43:02Z                                                NaN
# 10  2023-04-13T14:43:02Z                                                NaN
# 11  2023-04-13T14:43:02Z                                                NaN
# 12  2023-04-13T14:43:02Z                                                NaN
# 13  2023-04-13T14:43:02Z  {'id': 128187920, 'login': 'shrugify', 'gravat...
# 14  2023-04-13T14:43:01Z  {'id': 686745, 'login': 'pimcore', 'gravatar_i...
# 15  2023-04-13T14:43:02Z                                                NaN
# 16  2023-04-13T14:43:02Z                                                NaN
# 17  2023-04-13T14:43:02Z                                                NaN
# 18  2023-04-13T14:43:02Z                                                NaN
# 19  2023-04-13T14:43:02Z  {'id': 50414413, 'login': 'dof-dss', 'gravatar...
# 20  2023-04-13T14:43:02Z                                                NaN
# 21  2023-04-13T14:43:02Z                                                NaN
# 22  2023-04-13T14:43:02Z                                                NaN
# 23  2023-04-13T14:43:02Z                                                NaN
# 24  2023-04-13T14:43:02Z  {'id': 25665792, 'login': 'astarte-platform', ...
# 25  2023-04-13T14:43:02Z                                                NaN
# 26  2023-04-13T14:43:02Z                                                NaN
# 27  2023-04-13T14:43:02Z                                                NaN
# 28  2023-04-13T14:43:02Z  {'id': 686745, 'login': 'pimcore', 'gravatar_i...
# 29  2023-04-13T14:43:02Z                                                NaN

# %% [markdown]
# ##### Option 2: pd.json_normalize()
# You may notice above that many columns still contain dictionaries as values. We can correct this using json_normalize().
#
# https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html

# %%
pd.json_normalize(github_response)
# Out:
#              id                           type  public            created_at  \
# 0   28396254892                      PushEvent    True  2023-04-13T14:43:02Z
# 1   28396254822                      PushEvent    True  2023-04-13T14:43:02Z
# 2   28396254827                      PushEvent    True  2023-04-13T14:43:02Z
# 3   28396254883         PullRequestReviewEvent    True  2023-04-13T14:43:02Z
# 4   28396254809                      PushEvent    True  2023-04-13T14:43:02Z
# 5   28396254863                      PushEvent    True  2023-04-13T14:43:02Z
# 6   28396254820                      PushEvent    True  2023-04-13T14:43:02Z
# 7   28396254780                      PushEvent    True  2023-04-13T14:43:02Z
# 8   28396254806                    CreateEvent    True  2023-04-13T14:43:02Z
# 9   28396254782                    IssuesEvent    True  2023-04-13T14:43:02Z
# 10  28396254730                    DeleteEvent    True  2023-04-13T14:43:02Z
# 11  28396254789                      PushEvent    True  2023-04-13T14:43:02Z
# 12  28396254745                      PushEvent    True  2023-04-13T14:43:02Z
# 13  28396254749               PullRequestEvent    True  2023-04-13T14:43:02Z
# 14  28396254756  PullRequestReviewCommentEvent    True  2023-04-13T14:43:01Z
# 15  28396254719                      PushEvent    True  2023-04-13T14:43:02Z
# 16  28396254773               PullRequestEvent    True  2023-04-13T14:43:02Z
# 17  28396254617                      PushEvent    True  2023-04-13T14:43:02Z
# 18  28396254757               PullRequestEvent    True  2023-04-13T14:43:02Z
# 19  28396254727                    DeleteEvent    True  2023-04-13T14:43:02Z
# 20  28396254704                     WatchEvent    True  2023-04-13T14:43:02Z
# 21  28396254612                    PublicEvent    True  2023-04-13T14:43:02Z
# 22  28396254629                    CreateEvent    True  2023-04-13T14:43:02Z
# 23  28396254717                      PushEvent    True  2023-04-13T14:43:02Z
# 24  28396254644                      PushEvent    True  2023-04-13T14:43:02Z
# 25  28396254645                      PushEvent    True  2023-04-13T14:43:02Z
# 26  28396254702                      PushEvent    True  2023-04-13T14:43:02Z
# 27  28396254712                    CreateEvent    True  2023-04-13T14:43:02Z
# 28  28396254684         PullRequestReviewEvent    True  2023-04-13T14:43:02Z
# 29  28396254641                    CreateEvent    True  2023-04-13T14:43:02Z
#
#      actor.id      actor.login actor.display_login actor.gravatar_id  \
# 0    49699333  dependabot[bot]          dependabot
# 1   108680395       richardaeh          richardaeh
# 2    63110987  Anshika66-Gupta     Anshika66-Gupta
# 3    92680143            armru               armru
# 4     5972917           Kielek              Kielek
# 5     7548711      cardigliano         cardigliano
# 6   116730455     vntuananhbui        vntuananhbui
# 7   109960975       hwright-os          hwright-os
# 8   113639795      Dutra-Pedro         Dutra-Pedro
# 9    59863112   Nter-developer      Nter-developer
# 10  112381491        piasooriy           piasooriy
# 11   63140278          kenshgy             kenshgy
# 12   68828345       antikkorps          antikkorps
# 13    2636487             mteu                mteu
# 14   97134765     aryaantony92        aryaantony92
# 15  107903342          YUSUNOK             YUSUNOK
# 16   10810283  direwolf-github     direwolf-github
# 17    4802196         cerminar            cerminar
# 18  101598059   brandao-rafael      brandao-rafael
# 19     348030         DuttonMa            DuttonMa
# 20    5344654        yun900800           yun900800
# 21  107007336         Ben11029            Ben11029
# 22   10810283  direwolf-github     direwolf-github
# 23  118745830        Archeozyx           Archeozyx
# 24   56254275  astarte-machine     astarte-machine
# 25   76970935     xiaoandy1974        xiaoandy1974
# 26   77192131          rhd5656             rhd5656
# 27   43047562    scala-steward       scala-steward
# 28   97134765     aryaantony92        aryaantony92
# 29    4303697          Iaincox             Iaincox
#
#                                        actor.url  \
# 0   https://api.github.com/users/dependabot[bot]
# 1        https://api.github.com/users/richardaeh
# 2   https://api.github.com/users/Anshika66-Gupta
# 3             https://api.github.com/users/armru
# 4            https://api.github.com/users/Kielek
# 5       https://api.github.com/users/cardigliano
# 6      https://api.github.com/users/vntuananhbui
# 7        https://api.github.com/users/hwright-os
# 8       https://api.github.com/users/Dutra-Pedro
# 9    https://api.github.com/users/Nter-developer
# 10        https://api.github.com/users/piasooriy
# 11          https://api.github.com/users/kenshgy
# 12       https://api.github.com/users/antikkorps
# 13             https://api.github.com/users/mteu
# 14     https://api.github.com/users/aryaantony92
# 15          https://api.github.com/users/YUSUNOK
# 16  https://api.github.com/users/direwolf-github
# 17         https://api.github.com/users/cerminar
# 18   https://api.github.com/users/brandao-rafael
# 19         https://api.github.com/users/DuttonMa
# 20        https://api.github.com/users/yun900800
# 21         https://api.github.com/users/Ben11029
# 22  https://api.github.com/users/direwolf-github
# 23        https://api.github.com/users/Archeozyx
# 24  https://api.github.com/users/astarte-machine
# 25     https://api.github.com/users/xiaoandy1974
# 26          https://api.github.com/users/rhd5656
# 27    https://api.github.com/users/scala-steward
# 28     https://api.github.com/users/aryaantony92
# 29          https://api.github.com/users/Iaincox
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/49699333?  ...
# 1   https://avatars.githubusercontent.com/u/108680...  ...
# 2   https://avatars.githubusercontent.com/u/63110987?  ...
# 3   https://avatars.githubusercontent.com/u/92680143?  ...
# 4    https://avatars.githubusercontent.com/u/5972917?  ...
# 5    https://avatars.githubusercontent.com/u/7548711?  ...
# 6   https://avatars.githubusercontent.com/u/116730...  ...
# 7   https://avatars.githubusercontent.com/u/109960...  ...
# 8   https://avatars.githubusercontent.com/u/113639...  ...
# 9   https://avatars.githubusercontent.com/u/59863112?  ...
# 10  https://avatars.githubusercontent.com/u/112381...  ...
# 11  https://avatars.githubusercontent.com/u/63140278?  ...
# 12  https://avatars.githubusercontent.com/u/68828345?  ...
# 13   https://avatars.githubusercontent.com/u/2636487?  ...
# 14  https://avatars.githubusercontent.com/u/97134765?  ...
# 15  https://avatars.githubusercontent.com/u/107903...  ...
# 16  https://avatars.githubusercontent.com/u/10810283?  ...
# 17   https://avatars.githubusercontent.com/u/4802196?  ...
# 18  https://avatars.githubusercontent.com/u/101598...  ...
# 19    https://avatars.githubusercontent.com/u/348030?  ...
# 20   https://avatars.githubusercontent.com/u/5344654?  ...
# 21  https://avatars.githubusercontent.com/u/107007...  ...
# 22  https://avatars.githubusercontent.com/u/10810283?  ...
# 23  https://avatars.githubusercontent.com/u/118745...  ...
# 24  https://avatars.githubusercontent.com/u/56254275?  ...
# 25  https://avatars.githubusercontent.com/u/76970935?  ...
# 26  https://avatars.githubusercontent.com/u/77192131?  ...
# 27  https://avatars.githubusercontent.com/u/43047562?  ...
# 28  https://avatars.githubusercontent.com/u/97134765?  ...
# 29   https://avatars.githubusercontent.com/u/4303697?  ...
#
#     payload.pull_request.milestone.creator.site_admin  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                              False
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                              False
# 29                                                NaN
#
#    payload.pull_request.milestone.open_issues  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        2.0
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        2.0
# 29                                        NaN
#
#    payload.pull_request.milestone.closed_issues  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          0.0
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          0.0
# 29                                          NaN
#
#     payload.pull_request.milestone.state  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                  open
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                                   NaN
# 27                                   NaN
# 28                                  open
# 29                                   NaN
#
#     payload.pull_request.milestone.created_at  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                       2023-04-12T12:51:00Z
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                       2023-04-12T12:51:00Z
# 29                                        NaN
#
#     payload.pull_request.milestone.updated_at  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                       2023-04-13T14:35:52Z
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                       2023-04-13T14:35:52Z
# 29                                        NaN
#
#     payload.pull_request.milestone.due_on  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
#
#    payload.pull_request.milestone.closed_at  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
#
#    payload.pull_request.head.repo.license  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
#
#    payload.pull_request.base.repo.license
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
#
# [30 rows x 535 columns]

# %% [markdown]
# #### Selecting only certain values by iterating with a for loop
#
# If we only want to select certain parts of the JSON:
# - Option 1: make a DataFrame and drop the rest.
# - Option 2: Use a for loop to extract only the required information.
#
# https://www.w3schools.com/python/python_for_loops.asp
#
# https://www.w3schools.com/python/ref_func_range.asp

# %%
# login - first value
github_response[0]['actor']['login']
# Out:
# 'dependabot[bot]'

# %%
# repo - first value
github_response[0]['repo']['name']
# Out:
# 'SAP/inquirer-gui'

# %%
# event_type - first value
github_response[0]['type']
# Out:
# 'PushEvent'

# %%
# Empty lists that the loop will fill with values.
login = []
repo = []
event_type = []

for i in range(len(github_response)):
    # add the ith login value to the login list
    login.append(github_response[i]['actor']['login'])
    # add the ith repo name to the repo list
    repo.append(github_response[i]['repo']['name'])
    # add the ith event type to the event_type list
    event_type.append(github_response[i]['type'])

# %%
# Let's have a look at the login list.
login
# Out:
# ['dependabot[bot]',
#  'richardaeh',
#  'Anshika66-Gupta',
#  'armru',
#  'Kielek',
#  'cardigliano',
#  'vntuananhbui',
#  'hwright-os',
#  'Dutra-Pedro',
#  'Nter-developer',
#  'piasooriy',
#  'kenshgy',
#  'antikkorps',
#  'mteu',
#  'aryaantony92',
#  'YUSUNOK',
#  'direwolf-github',
#  'cerminar',
#  'brandao-rafael',
#  'DuttonMa',
#  'yun900800',
#  'Ben11029',
#  'direwolf-github',
#  'Archeozyx',
#  'astarte-machine',
#  'xiaoandy1974',
#  'rhd5656',
#  'scala-steward',
#  'aryaantony92',
#  'Iaincox']

# %%
# Let's have a look at the repo list.
repo
# Out:
# ['SAP/inquirer-gui',
#  'richardaeh/richardaeh.github.io',
#  'Anshika66-Gupta/New-Booking-Application',
#  'cloudnative-pg/cloudnative-pg',
#  'open-telemetry/opentelemetry-dotnet-instrumentation',
#  'ntop/ntopng',
#  'vntuananhbui/Infiniture-BookStore-Website',
#  'OrdnanceSurvey/OS-OpenMap-Local-stylesheets',
#  'Dutra-Pedro/TextArea',
#  'Nter-developer/bravo-HealthPark-BE',
#  'piasooriy/pias-bookstore',
#  'kenshgy/happy-wedding',
#  'antikkorps/globalAppV3',
#  'shrugify/yolo',
#  'pimcore/file-explorer-bundle',
#  'YUSUNOK/algorithm',
#  'direwolf-github/ephemeral-ci-c973b550',
#  'cerminar/cmssw',
#  'brandao-rafael/Aidioms_separated',
#  'dof-dss/nicsdru_unity',
#  'azarus/angular-dragndrop',
#  'Ben11029/chuangba',
#  'direwolf-github/ephemeral-ci-c973b550',
#  'StephanoNK/ASD-TR',
#  'astarte-platform/docs',
#  'xiaoandy1974/test',
#  'NK590/1Day1ProblemChallenge',
#  'scala-steward/fs2-kafka',
#  'pimcore/file-explorer-bundle',
#  'Iaincox/Shore.Fund']

# %%
# Let's have a look at the event_type list.
event_type
# Out:
# ['PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PullRequestReviewEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'CreateEvent',
#  'IssuesEvent',
#  'DeleteEvent',
#  'PushEvent',
#  'PushEvent',
#  'PullRequestEvent',
#  'PullRequestReviewCommentEvent',
#  'PushEvent',
#  'PullRequestEvent',
#  'PushEvent',
#  'PullRequestEvent',
#  'DeleteEvent',
#  'WatchEvent',
#  'PublicEvent',
#  'CreateEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'CreateEvent',
#  'PullRequestReviewEvent',
#  'CreateEvent']

# %% [markdown]
# ### International Space Station API - just another cool API
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'iss_position': {'latitude': '18.7634', 'longitude': '29.3619'},
#  'message': 'success',
#  'timestamp': 1681397282}

# %% [markdown]
# ## Spotipy

# %% [markdown]
# Now that you know all about APIs, let's use that knowledge on something even more fun.
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into a Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/authorization/app-settings/

# %% [markdown]
# #### Authentication
#
# With most APIs we need to autheticate ourself. This is often done with a username and a password. You will likely use a different username and password for most APIs, so make sure you're using a password manager, or keep everything written down somewhere safe.
#
# If ever you'd like more information about spotipy: [here are the docs](https://spotipy.readthedocs.io/en/2.19.0/).

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    #client_id="82d10cbeab244ba885a29af43becd014",
    #client_secret="b23ecbf78eb743b38161dae226870f4c"))

# %%
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    client_id="4f3178f82dd54838a2e06c9d4003a726", # 5b3311d52b2845cf9c3bf804ea93a3d2
    client_secret="7cfe8f28ffbc4b66afe9ea86a10e5cbf")) # 25b63863e2674da1a8a914ff62b53d04

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This method allows you to find songs using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
# Search for 'Lady Gaga', restricted to the first 10 results.

results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
# Only one key makes it seem like there'll be many subdictionaries, let's delve deeper.
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
# You can play the track by pasting the url in your browser.

# We can explore further by adding keys one after the other.

results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Bloody Mary'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: note the square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features contained in the search results:

# %%
# https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-tracks
# The popularity of the track. The value will be between 0 and 100, with 100 being the most popular.

results["tracks"]["items"][0]["popularity"]
# Out:
# 78

# %% [markdown]
# This is how Spotify identifies individual songs: with a Uniform Resource Identifier  or `uri`. (The `id` and the `url` are also ways to identify each song uniquely).

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:11BKm0j4eYoCPPpCONAVwA'

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chili Peppers and store the `uri` of the songs and their names.

# %%
# Send request and store the response.
red_hot = sp.search(q="Red Hot Chili Peppers", limit=10)

# Initialize empty lists that we will fill with information from our loop.
list_of_uri = []
list_of_song_names = []

# Iterate through the "items" (the songs),
# and append the "uri" and the "name" to the lists we created.
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# Print results.
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:64BbK9SFKH2jk86U3dGj2P', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:1G391cbiT3v3Cywg8T7DM1', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:0uppYCG86ajpV2hSR3dJJ0', 'spotify:track:2aibwv5hGXSgw7Yru8IYTO', 'spotify:track:10Nmj3JCNoMeBQ87uw5j8k', 'spotify:track:1f2V8U1BiWaC9aJWmpOARe', 'spotify:track:2oaK4JLVnmRGIO9ytBE1bt']
#
#
# ['Under the Bridge', 'Otherside', 'Californication', 'Scar Tissue', "Can't Stop", 'Give It Away', 'Snow (Hey Oh)', 'Dani California', 'By the Way', 'Dark Necessities']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results to a big list called `results`.

# %%
artists = ["Red Hot Chili Peppers", "SCARR", "Whitney Houston"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
# Let's look at the second element in the results list.
results[1]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=SCARR&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#        'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#        'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#        'name': 'Giveon',
#        'type': 'artist',
#        'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/64LkgCfNbLqjclQYCTid8L'},
#      'href': 'https://api.spotify.com/v1/albums/64LkgCfNbLqjclQYCTid8L',
#      'id': '64LkgCfNbLqjclQYCTid8L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732739e569d6b6d0e0abc8cd9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022739e569d6b6d0e0abc8cd9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512739e569d6b6d0e0abc8cd9b',
#        'width': 64}],
#      'name': 'Give Or Take',
#      'release_date': '2022-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:64LkgCfNbLqjclQYCTid8L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#       'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#       'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#       'name': 'Giveon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 178264,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12107667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5PSYn0XVImstXPFFDtajEK'},
#     'href': 'https://api.spotify.com/v1/tracks/5PSYn0XVImstXPFFDtajEK',
#     'id': '5PSYn0XVImstXPFFDtajEK',
#     'is_local': False,
#     'name': 'Scarred',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/351df4b9944e433a67a7dcc42e76932041d0421d?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5PSYn0XVImstXPFFDtajEK'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1z7cTlp6ckvLvVoZBMMNMQ'},
#        'href': 'https://api.spotify.com/v1/artists/1z7cTlp6ckvLvVoZBMMNMQ',
#        'id': '1z7cTlp6ckvLvVoZBMMNMQ',
#        'name': 'swoozydolphin',
#        'type': 'artist',
#        'uri': 'spotify:artist:1z7cTlp6ckvLvVoZBMMNMQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/38jv2P71u8Xp4VFJMzAasI'},
#      'href': 'https://api.spotify.com/v1/albums/38jv2P71u8Xp4VFJMzAasI',
#      'id': '38jv2P71u8Xp4VFJMzAasI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345484c4cebd679a9aff90dcc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245484c4cebd679a9aff90dcc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145484c4cebd679a9aff90dcc',
#        'width': 64}],
#      'name': 'swzgaze',
#      'release_date': '2021-04-16',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:38jv2P71u8Xp4VFJMzAasI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1z7cTlp6ckvLvVoZBMMNMQ'},
#       'href': 'https://api.spotify.com/v1/artists/1z7cTlp6ckvLvVoZBMMNMQ',
#       'id': '1z7cTlp6ckvLvVoZBMMNMQ',
#       'name': 'swoozydolphin',
#       'type': 'artist',
#       'uri': 'spotify:artist:1z7cTlp6ckvLvVoZBMMNMQ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 99001,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZES82132753'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/21hQmHixsf32jwujwGBThB'},
#     'href': 'https://api.spotify.com/v1/tracks/21hQmHixsf32jwujwGBThB',
#     'id': '21hQmHixsf32jwujwGBThB',
#     'is_local': False,
#     'name': 'SCARR',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/42ae140f9721b7ce3afb0f9196ec40d901b6a7b6?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:21hQmHixsf32jwujwGBThB'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4l7BJOIRyFkQT9QD96m8tu'},
#        'href': 'https://api.spotify.com/v1/artists/4l7BJOIRyFkQT9QD96m8tu',
#        'id': '4l7BJOIRyFkQT9QD96m8tu',
#        'name': 'Your Stepdad',
#        'type': 'artist',
#        'uri': 'spotify:artist:4l7BJOIRyFkQT9QD96m8tu'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4H1r7xLjoAKCQnWjsuL04G'},
#      'href': 'https://api.spotify.com/v1/albums/4H1r7xLjoAKCQnWjsuL04G',
#      'id': '4H1r7xLjoAKCQnWjsuL04G',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27367d7c635966e6aa383a164a3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0267d7c635966e6aa383a164a3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485167d7c635966e6aa383a164a3',
#        'width': 64}],
#      'name': 'sloppy secondaries',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4H1r7xLjoAKCQnWjsuL04G'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4l7BJOIRyFkQT9QD96m8tu'},
#       'href': 'https://api.spotify.com/v1/artists/4l7BJOIRyFkQT9QD96m8tu',
#       'id': '4l7BJOIRyFkQT9QD96m8tu',
#       'name': 'Your Stepdad',
#       'type': 'artist',
#       'uri': 'spotify:artist:4l7BJOIRyFkQT9QD96m8tu'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 71330,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZNMZ2164330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7kzGbfg49BXcvssmXH4iMC'},
#     'href': 'https://api.spotify.com/v1/tracks/7kzGbfg49BXcvssmXH4iMC',
#     'id': '7kzGbfg49BXcvssmXH4iMC',
#     'is_local': False,
#     'name': 'scar',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/67e161f595eabca0cd066572ed48ed1108ab3109?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7kzGbfg49BXcvssmXH4iMC'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IprNlQiJZUUJhDl0fL2SL'},
#        'href': 'https://api.spotify.com/v1/artists/4IprNlQiJZUUJhDl0fL2SL',
#        'id': '4IprNlQiJZUUJhDl0fL2SL',
#        'name': 'Quando Rondo',
#        'type': 'artist',
#        'uri': 'spotify:artist:4IprNlQiJZUUJhDl0fL2SL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2s19QcF1PIILzRfS6Jjni3'},
#      'href': 'https://api.spotify.com/v1/albums/2s19QcF1PIILzRfS6Jjni3',
#      'id': '2s19QcF1PIILzRfS6Jjni3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27301a870253a90ff8c53dce16e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0201a870253a90ff8c53dce16e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485101a870253a90ff8c53dce16e',
#        'width': 64}],
#      'name': 'From the Neighborhood to the Stage',
#      'release_date': '2019-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2s19QcF1PIILzRfS6Jjni3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IprNlQiJZUUJhDl0fL2SL'},
#       'href': 'https://api.spotify.com/v1/artists/4IprNlQiJZUUJhDl0fL2SL',
#       'id': '4IprNlQiJZUUJhDl0fL2SL',
#       'name': 'Quando Rondo',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IprNlQiJZUUJhDl0fL2SL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 207000,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21901934'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5CFvscpivObLfIVQtHyQxE'},
#     'href': 'https://api.spotify.com/v1/tracks/5CFvscpivObLfIVQtHyQxE',
#     'id': '5CFvscpivObLfIVQtHyQxE',
#     'is_local': False,
#     'name': 'Scarred From Love',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cd34f1df629fe74bb54756566e7d532c181a5530?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:5CFvscpivObLfIVQtHyQxE'},
#    {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0a3qFRPlQ5HrMGcuC2eHqH'},
#        'href': 'https://api.spotify.com/v1/artists/0a3qFRPlQ5HrMGcuC2eHqH',
#        'id': '0a3qFRPlQ5HrMGcuC2eHqH',
#        'name': 'SCAR',
#        'type': 'artist',
#        'uri': 'spotify:artist:0a3qFRPlQ5HrMGcuC2eHqH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2UFieLiYEApGBvG0Gmce7D'},
#      'href': 'https://api.spotify.com/v1/albums/2UFieLiYEApGBvG0Gmce7D',
#      'id': '2UFieLiYEApGBvG0Gmce7D',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27323082a9c1c045838668c5e6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0223082a9c1c045838668c5e6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485123082a9c1c045838668c5e6f',
#        'width': 64}],
#      'name': 'Kennenlernphasen',
#      'release_date': '2023-03-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2UFieLiYEApGBvG0Gmce7D'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0a3qFRPlQ5HrMGcuC2eHqH'},
#       'href': 'https://api.spotify.com/v1/artists/0a3qFRPlQ5HrMGcuC2eHqH',
#       'id': '0a3qFRPlQ5HrMGcuC2eHqH',
#       'name': 'SCAR',
#       'type': 'artist',
#       'uri': 'spotify:artist:0a3qFRPlQ5HrMGcuC2eHqH'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 121312,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZES82391797'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/329a9EzgGiJFeVH3wOBHUX'},
#     'href': 'https://api.spotify.com/v1/tracks/329a9EzgGiJFeVH3wOBHUX',
#     'id': '329a9EzgGiJFeVH3wOBHUX',
#     'is_local': False,
#     'name': 'Kennenlernphasen',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7ad8d76d76948c63c2c94ed5c87e0dbcb2703b09?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:329a9EzgGiJFeVH3wOBHUX'},
#    {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1sQHD0DIlJ8oElG6XMO2P3'},
#        'href': 'https://api.spotify.com/v1/artists/1sQHD0DIlJ8oElG6XMO2P3',
#        'id': '1sQHD0DIlJ8oElG6XMO2P3',
#        'name': 'Backdoor Sam',
#        'type': 'artist',
#        'uri': 'spotify:artist:1sQHD0DIlJ8oElG6XMO2P3'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#        'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#        'id': '579LsvZcRVKtToYjS0tkKz',
#        'name': 'Big Scarr',
#        'type': 'artist',
#        'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7aNeo8IwbTpv3sfFNgBiiV'},
#      'href': 'https://api.spotify.com/v1/albums/7aNeo8IwbTpv3sfFNgBiiV',
#      'id': '7aNeo8IwbTpv3sfFNgBiiV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27328d9631eac5ae7dafb55a333',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0228d9631eac5ae7dafb55a333',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485128d9631eac5ae7dafb55a333',
#        'width': 64}],
#      'name': "Scarred Baby's",
#      'release_date': '2022-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7aNeo8IwbTpv3sfFNgBiiV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1sQHD0DIlJ8oElG6XMO2P3'},
#       'href': 'https://api.spotify.com/v1/artists/1sQHD0DIlJ8oElG6XMO2P3',
#       'id': '1sQHD0DIlJ8oElG6XMO2P3',
#       'name': 'Backdoor Sam',
#       'type': 'artist',
#       'uri': 'spotify:artist:1sQHD0DIlJ8oElG6XMO2P3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#       'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#       'id': '579LsvZcRVKtToYjS0tkKz',
#       'name': 'Big Scarr',
#       'type': 'artist',
#       'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 193210,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1415638'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/57SN8XoR7SWUqWeRMCYAgm'},
#     'href': 'https://api.spotify.com/v1/tracks/57SN8XoR7SWUqWeRMCYAgm',
#     'id': '57SN8XoR7SWUqWeRMCYAgm',
#     'is_local': False,
#     'name': "Scarred Baby's",
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8accb43f29dc9315e2ec298c3e869dcffccdeef3?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:57SN8XoR7SWUqWeRMCYAgm'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ps6le7tj5BdNtdnfNgTU4'},
#        'href': 'https://api.spotify.com/v1/artists/3Ps6le7tj5BdNtdnfNgTU4',
#        'id': '3Ps6le7tj5BdNtdnfNgTU4',
#        'name': '6 Dogs',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Ps6le7tj5BdNtdnfNgTU4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zrXmqDEqtBFUZo6jedNf0'},
#        'href': 'https://api.spotify.com/v1/artists/6zrXmqDEqtBFUZo6jedNf0',
#        'id': '6zrXmqDEqtBFUZo6jedNf0',
#        'name': 'Danny Wolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zrXmqDEqtBFUZo6jedNf0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6c7scaeKyXfFQlLzrrE61c'},
#      'href': 'https://api.spotify.com/v1/albums/6c7scaeKyXfFQlLzrrE61c',
#      'id': '6c7scaeKyXfFQlLzrrE61c',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e048d70304449b04039456b8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e048d70304449b04039456b8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e048d70304449b04039456b8',
#        'width': 64}],
#      'name': '6 Wolves',
#      'release_date': '2018-05-04',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:6c7scaeKyXfFQlLzrrE61c'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ps6le7tj5BdNtdnfNgTU4'},
#       'href': 'https://api.spotify.com/v1/artists/3Ps6le7tj5BdNtdnfNgTU4',
#       'id': '3Ps6le7tj5BdNtdnfNgTU4',
#       'name': '6 Dogs',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Ps6le7tj5BdNtdnfNgTU4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zrXmqDEqtBFUZo6jedNf0'},
#       'href': 'https://api.spotify.com/v1/artists/6zrXmqDEqtBFUZo6jedNf0',
#       'id': '6zrXmqDEqtBFUZo6jedNf0',
#       'name': 'Danny Wolf',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zrXmqDEqtBFUZo6jedNf0'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 148607,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZ5FA1752380'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5rnpeh10Rfdw1FEkBWkU7T'},
#     'href': 'https://api.spotify.com/v1/tracks/5rnpeh10Rfdw1FEkBWkU7T',
#     'id': '5rnpeh10Rfdw1FEkBWkU7T',
#     'is_local': False,
#     'name': 'Scar',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b4d9582780c1585b585b8f7fb7e519064626a795?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5rnpeh10Rfdw1FEkBWkU7T'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#        'href': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK',
#        'id': '5f7VJjfbwm532GiveGC0ZK',
#        'name': 'Lil Baby',
#        'type': 'artist',
#        'uri': 'spotify:artist:5f7VJjfbwm532GiveGC0ZK'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
# ...
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 197529,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG12000034'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ge7BHazYbVKi8qyZUX1Bm'},
#     'href': 'https://api.spotify.com/v1/tracks/7ge7BHazYbVKi8qyZUX1Bm',
#     'id': '7ge7BHazYbVKi8qyZUX1Bm',
#     'is_local': False,
#     'name': 'Emotionally Scarred',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/88791f7de3d9eac6d2a26ec354c0a5328e1e5d28?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:7ge7BHazYbVKi8qyZUX1Bm'},
#    {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5COD136qwj9wtuea78EGbF'},
#        'href': 'https://api.spotify.com/v1/artists/5COD136qwj9wtuea78EGbF',
#        'id': '5COD136qwj9wtuea78EGbF',
#        'name': 'Parker Jack',
#        'type': 'artist',
#        'uri': 'spotify:artist:5COD136qwj9wtuea78EGbF'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5webehDlzqsSapoO8wmwNA'},
#        'href': 'https://api.spotify.com/v1/artists/5webehDlzqsSapoO8wmwNA',
#        'id': '5webehDlzqsSapoO8wmwNA',
#        'name': 'Chyde',
#        'type': 'artist',
#        'uri': 'spotify:artist:5webehDlzqsSapoO8wmwNA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6rrxX9oYAnc4DyFfszt7r4'},
#      'href': 'https://api.spotify.com/v1/albums/6rrxX9oYAnc4DyFfszt7r4',
#      'id': '6rrxX9oYAnc4DyFfszt7r4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a078f9f7c9e941ebd59e87d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a078f9f7c9e941ebd59e87d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a078f9f7c9e941ebd59e87d0',
#        'width': 64}],
#      'name': 'SCARS',
#      'release_date': '2022-06-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6rrxX9oYAnc4DyFfszt7r4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5COD136qwj9wtuea78EGbF'},
#       'href': 'https://api.spotify.com/v1/artists/5COD136qwj9wtuea78EGbF',
#       'id': '5COD136qwj9wtuea78EGbF',
#       'name': 'Parker Jack',
#       'type': 'artist',
#       'uri': 'spotify:artist:5COD136qwj9wtuea78EGbF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5webehDlzqsSapoO8wmwNA'},
#       'href': 'https://api.spotify.com/v1/artists/5webehDlzqsSapoO8wmwNA',
#       'id': '5webehDlzqsSapoO8wmwNA',
#       'name': 'Chyde',
#       'type': 'artist',
#       'uri': 'spotify:artist:5webehDlzqsSapoO8wmwNA'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 173964,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZK6M2276376'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6718FOfpHgSR8fBTaJahHK'},
#     'href': 'https://api.spotify.com/v1/tracks/6718FOfpHgSR8fBTaJahHK',
#     'id': '6718FOfpHgSR8fBTaJahHK',
#     'is_local': False,
#     'name': 'SCARS',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a73a843c53dad7d5cfe99edc9214c21629e73f18?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6718FOfpHgSR8fBTaJahHK'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HWC3HweNpFwBU00BNVCCq'},
#        'href': 'https://api.spotify.com/v1/artists/6HWC3HweNpFwBU00BNVCCq',
#        'id': '6HWC3HweNpFwBU00BNVCCq',
#        'name': 'Luke',
#        'type': 'artist',
#        'uri': 'spotify:artist:6HWC3HweNpFwBU00BNVCCq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7lccXBuQ92VhUbWM2nPQmo'},
#      'href': 'https://api.spotify.com/v1/albums/7lccXBuQ92VhUbWM2nPQmo',
#      'id': '7lccXBuQ92VhUbWM2nPQmo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27388e50ceec20521397129c929',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0288e50ceec20521397129c929',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485188e50ceec20521397129c929',
#        'width': 64}],
#      'name': 'Scandalous - The All Star Compilation',
#      'release_date': '2014',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7lccXBuQ92VhUbWM2nPQmo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HWC3HweNpFwBU00BNVCCq'},
#       'href': 'https://api.spotify.com/v1/artists/6HWC3HweNpFwBU00BNVCCq',
#       'id': '6HWC3HweNpFwBU00BNVCCq',
#       'name': 'Luke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6HWC3HweNpFwBU00BNVCCq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/12FHARd9fY0Tu0ila4Ua25'},
#       'href': 'https://api.spotify.com/v1/artists/12FHARd9fY0Tu0ila4Ua25',
#       'id': '12FHARd9fY0Tu0ila4Ua25',
#       'name': 'Trick Daddy',
#       'type': 'artist',
#       'uri': 'spotify:artist:12FHARd9fY0Tu0ila4Ua25'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 206053,
#     'explicit': True,
#     'external_ids': {'isrc': 'USJ3V1822275'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0NXA8wKGM6eRgLzpJXanGL'},
#     'href': 'https://api.spotify.com/v1/tracks/0NXA8wKGM6eRgLzpJXanGL',
#     'id': '0NXA8wKGM6eRgLzpJXanGL',
#     'is_local': False,
#     'name': 'Scarred',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/566da6237fc268cead5a919f192c84e747c5a7df?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:0NXA8wKGM6eRgLzpJXanGL'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=SCARR&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %% [markdown]
# We can iterate through the `results` list and get just the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Otherside',
#  'Californication',
#  'Scar Tissue',
#  "Can't Stop",
#  'Give It Away',
#  'Snow (Hey Oh)',
#  'Dani California',
#  'By the Way',
#  'Dark Necessities',
#  'Scarred',
#  'SCARR',
#  'scar',
#  'Scarred From Love',
#  'Kennenlernphasen',
#  "Scarred Baby's",
#  'Scar',
#  'Emotionally Scarred',
#  'SCARS',
#  'Scarred',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'I Will Always Love You',
#  'Higher Love',
#  'I Have Nothing',
#  'How Will I Know',
#  'Greatest Love of All',
#  'Higher Love',
#  "It's Not Right But It's Okay",
#  'How Will I Know',
#  'Saving All My Love for You']

# %% [markdown]
# ### Playlists
#
# Using spotipy, we can both build and read spotify playlists. Today, we will only show you how to read information from a playlist. However, if you wish to build one, we strongly encourage you read the [documentation](https://spotipy.readthedocs.io/en/2.19.0/) and explore further.

# %%
my_playlist = sp.user_playlist_tracks(user="spotify", playlist_id="spotify:playlist:0ce6Rmxf7QXroqa1wzjWY8")

# %% [markdown]
# Extract songs ID from a playlist

# %%
my_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0ce6Rmxf7QXroqa1wzjWY8/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-09-22T07:34:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#        'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#        'id': '579T5fNgfbDetyamUTAetw',
#        'name': 'S+C+A+R+R',
#        'type': 'artist',
#        'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ZwTPVgvwIMxJh2GAdsaaP'},
#      'href': 'https://api.spotify.com/v1/albums/5ZwTPVgvwIMxJh2GAdsaaP',
#      'id': '5ZwTPVgvwIMxJh2GAdsaaP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27331df83ec065ed0a42cc82670',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0231df83ec065ed0a42cc82670',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485131df83ec065ed0a42cc82670',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'You\'re the One (From "I Lost My Body")',
#      'release_date': '2019-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5ZwTPVgvwIMxJh2GAdsaaP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#       'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#       'id': '579T5fNgfbDetyamUTAetw',
#       'name': 'S+C+A+R+R',
#       'type': 'artist',
#       'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 167986,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6F31902770'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Tnx4R7Gwj1LZsfssfzchh'},
#     'href': 'https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1LZsfssfzchh',
#     'id': '5Tnx4R7Gwj1LZsfssfzchh',
#     'is_local': False,
#     'name': 'You\'re the One - From "I Lost My Body"',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/613f49f1c8fecb4660754e696bdc2a4b91dae868?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#        'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#        'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#        'name': 'Manchester Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hruYceqit29o6m4arpAql'},
#      'href': 'https://api.spotify.com/v1/albums/4hruYceqit29o6m4arpAql',
#      'id': '4hruYceqit29o6m4arpAql',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736827146a676dafc0357fa665',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026827146a676dafc0357fa665',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516827146a676dafc0357fa665',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'A Black Mile To The Surface',
#      'release_date': '2017-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4hruYceqit29o6m4arpAql'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#       'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#       'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#       'name': 'Manchester Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 328933,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R1702133'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5eKfpH2dQ7FltCqb7LWEGJ'},
#     'href': 'https://api.spotify.com/v1/tracks/5eKfpH2dQ7FltCqb7LWEGJ',
#     'id': '5eKfpH2dQ7FltCqb7LWEGJ',
#     'is_local': False,
#     'name': 'The Alien',
#     'popularity': 47,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rqPrJjVzB01kfoQpz6XNe'},
#        'href': 'https://api.spotify.com/v1/artists/1rqPrJjVzB01kfoQpz6XNe',
#        'id': '1rqPrJjVzB01kfoQpz6XNe',
#        'name': 'Nina & Frederik',
#        'type': 'artist',
#        'uri': 'spotify:artist:1rqPrJjVzB01kfoQpz6XNe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/63obBSI5HlMFoawrrq8RDG'},
#      'href': 'https://api.spotify.com/v1/albums/63obBSI5HlMFoawrrq8RDG',
#      'id': '63obBSI5HlMFoawrrq8RDG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a287436c88bfedf3892dcaea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a287436c88bfedf3892dcaea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a287436c88bfedf3892dcaea',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Vintage World Nº10- EPs Collectors "Oh, Pecador" "Oh, Sinner Man"',
#      'release_date': '1958-05-06',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:63obBSI5HlMFoawrrq8RDG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rqPrJjVzB01kfoQpz6XNe'},
#       'href': 'https://api.spotify.com/v1/artists/1rqPrJjVzB01kfoQpz6XNe',
#       'id': '1rqPrJjVzB01kfoQpz6XNe',
#       'name': 'Nina & Frederik',
#       'type': 'artist',
#       'uri': 'spotify:artist:1rqPrJjVzB01kfoQpz6XNe'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'MK',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET'],
#     'disc_number': 1,
#     'duration_ms': 145773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560979249'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0R3OcHrzq3f8raukyZgTAc'},
#     'href': 'https://api.spotify.com/v1/tracks/0R3OcHrzq3f8raukyZgTAc',
#     'id': '0R3OcHrzq3f8raukyZgTAc',
#     'is_local': False,
#     'name': 'Oh, Pecador (Oh, Sinne Man)',
#     'popularity': 2,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d153551fd0ad9886707bb59c83760db3055fe94a?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0R3OcHrzq3f8raukyZgTAc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#        'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#        'id': '2G7QgTep5IsJHGHm1hXygD',
#        'name': 'Kid Francescoli',
#        'type': 'artist',
#        'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4iII9nfzjxOYQFp8PyV6HD'},
#      'href': 'https://api.spotify.com/v1/albums/4iII9nfzjxOYQFp8PyV6HD',
#      'id': '4iII9nfzjxOYQFp8PyV6HD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737fc1ed797a7ef1dd805b5bc5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027fc1ed797a7ef1dd805b5bc5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517fc1ed797a7ef1dd805b5bc5',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Play Me Again',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4iII9nfzjxOYQFp8PyV6HD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#       'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#       'id': '2G7QgTep5IsJHGHm1hXygD',
#       'name': 'Kid Francescoli',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/63fbQTZ9yW3SUsBRYcn1Wm'},
#       'href': 'https://api.spotify.com/v1/artists/63fbQTZ9yW3SUsBRYcn1Wm',
#       'id': '63fbQTZ9yW3SUsBRYcn1Wm',
#       'name': 'Julia Minkin',
#       'type': 'artist',
#       'uri': 'spotify:artist:63fbQTZ9yW3SUsBRYcn1Wm'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 390638,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRP621600280'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/24upABZ8A0sAepfu91sEYr'},
#     'href': 'https://api.spotify.com/v1/tracks/24upABZ8A0sAepfu91sEYr',
#     'id': '24upABZ8A0sAepfu91sEYr',
#     'is_local': False,
#     'name': 'Moon (And It Went Like)',
#     'popularity': 25,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:24upABZ8A0sAepfu91sEYr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#        'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#        'id': '4aEnNH9PuU1HF3TsZTru54',
#        'name': 'Caribou',
#        'type': 'artist',
#        'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NqhnYAVqlHuPG2OlgKSZy'},
#      'href': 'https://api.spotify.com/v1/albums/1NqhnYAVqlHuPG2OlgKSZy',
#      'id': '1NqhnYAVqlHuPG2OlgKSZy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273db02bfcbd6808d71afb2a3bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02db02bfcbd6808d71afb2a3bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851db02bfcbd6808d71afb2a3bf',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Never Come Back',
#      'release_date': '2020-01-28',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1NqhnYAVqlHuPG2OlgKSZy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#       'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#       'id': '4aEnNH9PuU1HF3TsZTru54',
#       'name': 'Caribou',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 305480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED622000007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IBrKDuBlyz3vW9JFCux10'},
#     'href': 'https://api.spotify.com/v1/tracks/7IBrKDuBlyz3vW9JFCux10',
#     'id': '7IBrKDuBlyz3vW9JFCux10',
#     'is_local': False,
#     'name': 'Never Come Back',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7IBrKDuBlyz3vW9JFCux10'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#        'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#        'id': '6wH6iStAh4KIaWfuhf0NYM',
#        'name': 'Manu Chao',
#        'type': 'artist',
#        'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6sLpbLsD1LlXnlCRjt8YuE'},
#      'href': 'https://api.spotify.com/v1/albums/6sLpbLsD1LlXnlCRjt8YuE',
#      'id': '6sLpbLsD1LlXnlCRjt8YuE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381d487c754295e61521aadcc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281d487c754295e61521aadcc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181d487c754295e61521aadcc',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Proxima Estacion : Esperanza',
#      'release_date': '2001',
#      'release_date_precision': 'year',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:6sLpbLsD1LlXnlCRjt8YuE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#       'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#       'id': '6wH6iStAh4KIaWfuhf0NYM',
#       'name': 'Manu Chao',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 114920,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR84R0100008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ecVMxkn0sJ3nlx1uS0IVN'},
#     'href': 'https://api.spotify.com/v1/tracks/3ecVMxkn0sJ3nlx1uS0IVN',
#     'id': '3ecVMxkn0sJ3nlx1uS0IVN',
#     'is_local': False,
#     'name': 'Trapped By Love',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:3ecVMxkn0sJ3nlx1uS0IVN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:50:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#        'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#        'id': '5v74mT11KGJqadf9sLw4dA',
#        'name': 'Cannonball Adderley',
#        'type': 'artist',
#        'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JpHin9lKOyizuJhKxaHWp'},
#      'href': 'https://api.spotify.com/v1/albums/5JpHin9lKOyizuJhKxaHWp',
#      'id': '5JpHin9lKOyizuJhKxaHWp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27385827d636962ea87b858ab32',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0285827d636962ea87b858ab32',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485185827d636962ea87b858ab32',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Jazz Profile: Cannonball Adderley',
#      'release_date': '1997-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5JpHin9lKOyizuJhKxaHWp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#       'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#       'id': '5v74mT11KGJqadf9sLw4dA',
#       'name': 'Cannonball Adderley',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 313200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA29000136'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6NF8MZ2trxckVBr82pyyPt'},
#     'href': 'https://api.spotify.com/v1/tracks/6NF8MZ2trxckVBr82pyyPt',
#     'id': '6NF8MZ2trxckVBr82pyyPt',
#     'is_local': False,
#     'name': 'Mercy, Mercy, Mercy',
#     'popularity': 55,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6NF8MZ2trxckVBr82pyyPt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#        'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#        'id': '3ayds6VIVBx3CU5NSNCDbq',
#        'name': 'Jacques Dutronc',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2S4mgB4hHSszPRGoYrGJ0d'},
#      'href': 'https://api.spotify.com/v1/albums/2S4mgB4hHSszPRGoYrGJ0d',
#      'id': '2S4mgB4hHSszPRGoYrGJ0d',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a28387fcc6e1c7ed11d82022',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a28387fcc6e1c7ed11d82022',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a28387fcc6e1c7ed11d82022',
#        'width': 64}],
#      'is_playable': True,
#      'name': "L' aventurier",
#      'release_date': '1969-06-30',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2S4mgB4hHSszPRGoYrGJ0d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#       'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#       'id': '3ayds6VIVBx3CU5NSNCDbq',
#       'name': 'Jacques Dutronc',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 155600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ196900030'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6FwkZ5lYdCUh1mzI1Bhojn'},
#     'href': 'https://api.spotify.com/v1/tracks/6FwkZ5lYdCUh1mzI1Bhojn',
#     'id': '6FwkZ5lYdCUh1mzI1Bhojn',
#     'is_local': False,
#     'name': 'Le responsable',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f57b6b9b44d64ab34f22fd5a1dfe369a2dd6f572?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6FwkZ5lYdCUh1mzI1Bhojn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#        'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#        'id': '2AR42Ur9PcchQDtEdwkv4L',
#        'name': 'Floating Points',
#        'type': 'artist',
#        'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1WwZwdTICfaZI51BIIEN9z'},
#      'href': 'https://api.spotify.com/v1/albums/1WwZwdTICfaZI51BIIEN9z',
#      'id': '1WwZwdTICfaZI51BIIEN9z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d03dff7f5eeee485e5a45f62',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d03dff7f5eeee485e5a45f62',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d03dff7f5eeee485e5a45f62',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Crush',
#      'release_date': '2019-10-18',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1WwZwdTICfaZI51BIIEN9z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#       'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#       'id': '2AR42Ur9PcchQDtEdwkv4L',
#       'name': 'Floating Points',
#       'type': 'artist',
#       'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
# ...
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2adSO4KU3FDjeM1PXCRDZm'},
#      'href': 'https://api.spotify.com/v1/albums/2adSO4KU3FDjeM1PXCRDZm',
#      'id': '2adSO4KU3FDjeM1PXCRDZm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f461bbc21a9bcec43a926973',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f461bbc21a9bcec43a926973',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f461bbc21a9bcec43a926973',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'The Business',
#      'release_date': '2020-09-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2adSO4KU3FDjeM1PXCRDZm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#       'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#       'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#       'name': 'Tiësto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 164000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CYA112000624'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6f3Slt0GbA2bPZlz0aIFXN'},
#     'href': 'https://api.spotify.com/v1/tracks/6f3Slt0GbA2bPZlz0aIFXN',
#     'id': '6f3Slt0GbA2bPZlz0aIFXN',
#     'is_local': False,
#     'name': 'The Business',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e516723e41dab08c241fc981aeed21407f322d72?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6f3Slt0GbA2bPZlz0aIFXN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:53:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/not_invented_here'},
#     'href': 'https://api.spotify.com/v1/users/not_invented_here',
#     'id': 'not_invented_here',
#     'type': 'user',
#     'uri': 'spotify:user:not_invented_here'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#        'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#        'id': '7qmf5YAQYjfjBF9C7kkjzs',
#        'name': 'Johnny Hooker',
#        'type': 'artist',
#        'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0kelpiZssyYlVNks8cHEth'},
#      'href': 'https://api.spotify.com/v1/albums/0kelpiZssyYlVNks8cHEth',
#      'id': '0kelpiZssyYlVNks8cHEth',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d5ac815f4676b21c60bfdc8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d5ac815f4676b21c60bfdc8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d5ac815f4676b21c60bfdc8',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Eu Vou Fazer uma Macumba Pra Te Amarrar, Maldito!',
#      'release_date': '2015-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0kelpiZssyYlVNks8cHEth'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#       'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#       'id': '7qmf5YAQYjfjBF9C7kkjzs',
#       'name': 'Johnny Hooker',
#       'type': 'artist',
#       'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 285000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'uscgh1563538'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7uSdpAkxgB0948bW7yjjJO'},
#     'href': 'https://api.spotify.com/v1/tracks/7uSdpAkxgB0948bW7yjjJO',
#     'id': '7uSdpAkxgB0948bW7yjjJO',
#     'is_local': False,
#     'name': 'Amor Marginal',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7uSdpAkxgB0948bW7yjjJO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:53:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/shokoshock'},
#     'href': 'https://api.spotify.com/v1/users/shokoshock',
#     'id': 'shokoshock',
#     'type': 'user',
#     'uri': 'spotify:user:shokoshock'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#        'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#        'id': '0YMeriqrS3zgsX24nfY0F0',
#        'name': 'The Tragically Hip',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6fRGXiRnTyLLRDXpXkrK1n'},
#      'href': 'https://api.spotify.com/v1/albums/6fRGXiRnTyLLRDXpXkrK1n',
#      'id': '6fRGXiRnTyLLRDXpXkrK1n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb5ebaaa20f7d208ce1caa14',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb5ebaaa20f7d208ce1caa14',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb5ebaaa20f7d208ce1caa14',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Yer Favourites',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 37,
#      'type': 'album',
#      'uri': 'spotify:album:6fRGXiRnTyLLRDXpXkrK1n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#       'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#       'id': '0YMeriqrS3zgsX24nfY0F0',
#       'name': 'The Tragically Hip',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 225426,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAM199600015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5nC2BQzszGGkZi7cvxFzH4'},
#     'href': 'https://api.spotify.com/v1/tracks/5nC2BQzszGGkZi7cvxFzH4',
#     'id': '5nC2BQzszGGkZi7cvxFzH4',
#     'is_local': False,
#     'name': 'Ahead By A Century',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5nC2BQzszGGkZi7cvxFzH4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T13:02:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/vaxgmeceb7pigybrcc3fdlhiw'},
#     'href': 'https://api.spotify.com/v1/users/vaxgmeceb7pigybrcc3fdlhiw',
#     'id': 'vaxgmeceb7pigybrcc3fdlhiw',
#     'type': 'user',
#     'uri': 'spotify:user:vaxgmeceb7pigybrcc3fdlhiw'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#        'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#        'id': '7zsin6IgVsR1rqSRCNYDwq',
#        'name': 'Family of the Year',
#        'type': 'artist',
#        'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14SCnv027L0HidHq0URIDu'},
#      'href': 'https://api.spotify.com/v1/albums/14SCnv027L0HidHq0URIDu',
#      'id': '14SCnv027L0HidHq0URIDu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731980a53c08d4911caa77d249',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021980a53c08d4911caa77d249',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511980a53c08d4911caa77d249',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Loma Vista',
#      'release_date': '2012-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:14SCnv027L0HidHq0URIDu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#       'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#       'id': '7zsin6IgVsR1rqSRCNYDwq',
#       'name': 'Family of the Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 190280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAN111200237'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6GRDI9suQHikFP6euIXnpq'},
#     'href': 'https://api.spotify.com/v1/tracks/6GRDI9suQHikFP6euIXnpq',
#     'id': '6GRDI9suQHikFP6euIXnpq',
#     'is_local': False,
#     'name': 'Hero',
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6GRDI9suQHikFP6euIXnpq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-29T14:22:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/8em1nqrnfspx3alyw0rz3ggn1'},
#     'href': 'https://api.spotify.com/v1/users/8em1nqrnfspx3alyw0rz3ggn1',
#     'id': '8em1nqrnfspx3alyw0rz3ggn1',
#     'type': 'user',
#     'uri': 'spotify:user:8em1nqrnfspx3alyw0rz3ggn1'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#        'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#        'id': '58r1rB5t3VF5X6yXGPequV',
#        'name': 'Maverick City Music',
#        'type': 'artist',
#        'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0prxUuXzlIyjSJU9ej003n'},
#      'href': 'https://api.spotify.com/v1/albums/0prxUuXzlIyjSJU9ej003n',
#      'id': '0prxUuXzlIyjSJU9ej003n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732176cda6fb0f4db7dbb6f1fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022176cda6fb0f4db7dbb6f1fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512176cda6fb0f4db7dbb6f1fb',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Maverick City Vol. 3 Part 1',
#      'release_date': '2020-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0prxUuXzlIyjSJU9ej003n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#       'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#       'id': '58r1rB5t3VF5X6yXGPequV',
#       'name': 'Maverick City Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nO7Yt0Jon48sqKR6VME4T'},
#       'href': 'https://api.spotify.com/v1/artists/5nO7Yt0Jon48sqKR6VME4T',
#       'id': '5nO7Yt0Jon48sqKR6VME4T',
#       'name': 'Joe L Barnes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nO7Yt0Jon48sqKR6VME4T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rc8nzClXj7sUjvsHVg6AD'},
#       'href': 'https://api.spotify.com/v1/artists/4rc8nzClXj7sUjvsHVg6AD',
#       'id': '4rc8nzClXj7sUjvsHVg6AD',
#       'name': 'Naomi Raine',
#       'type': 'artist',
#       'uri': 'spotify:artist:4rc8nzClXj7sUjvsHVg6AD'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 646239,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAET2042835'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0aZFEiDKLK2B4gzPaGCZVm'},
#     'href': 'https://api.spotify.com/v1/tracks/0aZFEiDKLK2B4gzPaGCZVm',
#     'id': '0aZFEiDKLK2B4gzPaGCZVm',
#     'is_local': False,
#     'name': 'Promises',
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0aZFEiDKLK2B4gzPaGCZVm'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 16}

# %%
my_playlist["items"][0]["track"]["uri"]
# Out:
# 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'

# %% [markdown]
# ### Audio features
#
# You can check an explanation of the audio features [here](https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/).

# %%
sp.audio_features("spotify:track:6Sy9BUbgFse0n0LPA5lwy5")
# Out:
# [{'danceability': 0.528,
#   'energy': 0.965,
#   'key': 11,
#   'loudness': -7.984,
#   'mode': 0,
#   'speechiness': 0.0465,
#   'acousticness': 0.141,
#   'instrumentalness': 0.985,
#   'liveness': 0.0797,
#   'valence': 0.587,
#   'tempo': 136.065,
#   'type': 'audio_features',
#   'id': '6Sy9BUbgFse0n0LPA5lwy5',
#   'uri': 'spotify:track:6Sy9BUbgFse0n0LPA5lwy5',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Sy9BUbgFse0n0LPA5lwy5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sy9BUbgFse0n0LPA5lwy5',
#   'duration_ms': 225493,
#   'time_signature': 4}]

# %% [markdown]
# ### Creating a function that takes a song name and returns its audio features

# %%
list_of_songs = []

def song_features(human_song_title):
    # Search for the song title you enter into the function, limited to the first 10 results.
    results = sp.search(q=human_song_title, limit = 10)['tracks']['items']
    
    # Create a loop, so we only select the parts of the json we need.
    for i in results:

        # Empty dictionary to be filled with the information below.
        track_dict = {}

        # Add the key artist and a corresponding value to the dictionary.
        track_dict['Artist'] = i['artists'][0]['name']
        # Add the key title and the corresponding value to the dictionary.
        track_dict['Title'] = i['name'] 
        # Add the key album and the corresponding value to the dictionary.
        track_dict['Album'] = i['album']['name']
        # Add the key audio description and the corresponding value to the dictionary.
        track_dict['Audio Description'] = sp.audio_features(i['id'])
        
        # Add the dictionary to the list list_of_songs.
        list_of_songs.append(track_dict)
    # Output list_of_songs.
    return list_of_songs

# Call the function with a song to test.
song_features("Under the Bridge")
# Out:
# [{'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'Blood Sugar Sex Magik (Deluxe Edition)',
#   'Audio Description': [{'danceability': 0.559,
#     'energy': 0.345,
#     'key': 4,
#     'loudness': -13.496,
#     'mode': 1,
#     'speechiness': 0.0459,
#     'acousticness': 0.0576,
#     'instrumentalness': 0.000105,
#     'liveness': 0.141,
#     'valence': 0.458,
#     'tempo': 84.581,
#     'type': 'audio_features',
#     'id': '3d9DChrdc6BOeFsbrZ3Is0',
#     'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0',
#     'track_href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d9DChrdc6BOeFsbrZ3Is0',
#     'duration_ms': 264307,
#     'time_signature': 4}]},
#  {'Artist': 'owlh',
#   'Title': 'Under the Bridge',
#   'Album': 'cover to cover',
#   'Audio Description': [{'danceability': 0.781,
#     'energy': 0.355,
#     'key': 9,
#     'loudness': -8.158,
#     'mode': 1,
#     'speechiness': 0.0376,
#     'acousticness': 0.471,
#     'instrumentalness': 0.878,
#     'liveness': 0.125,
#     'valence': 0.363,
#     'tempo': 131.978,
#     'type': 'audio_features',
#     'id': '1AyRpRvLwUwkXwGGuNZHmN',
#     'uri': 'spotify:track:1AyRpRvLwUwkXwGGuNZHmN',
#     'track_href': 'https://api.spotify.com/v1/tracks/1AyRpRvLwUwkXwGGuNZHmN',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1AyRpRvLwUwkXwGGuNZHmN',
#     'duration_ms': 244196,
#     'time_signature': 4}]},
#  {'Artist': 'Adele',
#   'Title': 'Water Under the Bridge',
#   'Album': '25',
#   'Audio Description': [{'danceability': 0.59,
#     'energy': 0.833,
#     'key': 5,
#     'loudness': -6.503,
#     'mode': 0,
#     'speechiness': 0.0615,
#     'acousticness': 0.0142,
#     'instrumentalness': 5.4e-06,
#     'liveness': 0.105,
#     'valence': 0.538,
#     'tempo': 94.963,
#     'type': 'audio_features',
#     'id': '4jL6WWKFDqCOPo2hC3VhSS',
#     'uri': 'spotify:track:4jL6WWKFDqCOPo2hC3VhSS',
#     'track_href': 'https://api.spotify.com/v1/tracks/4jL6WWKFDqCOPo2hC3VhSS',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jL6WWKFDqCOPo2hC3VhSS',
#     'duration_ms': 240439,
#     'time_signature': 4}]},
#  {'Artist': 'Sam Hunt',
#   'Title': 'Water Under The Bridge',
#   'Album': 'Water Under The Bridge',
#   'Audio Description': [{'danceability': 0.635,
#     'energy': 0.866,
#     'key': 5,
#     'loudness': -2.695,
#     'mode': 1,
#     'speechiness': 0.0473,
#     'acousticness': 0.0697,
#     'instrumentalness': 0,
#     'liveness': 0.0955,
#     'valence': 0.853,
#     'tempo': 133.889,
#     'type': 'audio_features',
#     'id': '4viFAHmivkYQKkwLvwKOgg',
#     'uri': 'spotify:track:4viFAHmivkYQKkwLvwKOgg',
#     'track_href': 'https://api.spotify.com/v1/tracks/4viFAHmivkYQKkwLvwKOgg',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4viFAHmivkYQKkwLvwKOgg',
#     'duration_ms': 169760,
#     'time_signature': 4}]},
#  {'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'The Studio Album Collection 1991 - 2011',
#   'Audio Description': [{'danceability': 0.554,
#     'energy': 0.49,
#     'key': 4,
#     'loudness': -8.046,
#     'mode': 1,
#     'speechiness': 0.0457,
#     'acousticness': 0.0168,
#     'instrumentalness': 0.000534,
#     'liveness': 0.136,
#     'valence': 0.513,
#     'tempo': 84.275,
#     'type': 'audio_features',
#     'id': '1MMlmA1APa0MevW3Bm2PpE',
#     'uri': 'spotify:track:1MMlmA1APa0MevW3Bm2PpE',
#     'track_href': 'https://api.spotify.com/v1/tracks/1MMlmA1APa0MevW3Bm2PpE',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1MMlmA1APa0MevW3Bm2PpE',
#     'duration_ms': 265507,
#     'time_signature': 4}]},
#  {'Artist': 'The Drifters',
#   'Title': 'Under the Boardwalk',
#   'Album': 'Under the Boardwalk',
#   'Audio Description': [{'danceability': 0.747,
#     'energy': 0.226,
#     'key': 7,
#     'loudness': -13.635,
#     'mode': 1,
#     'speechiness': 0.0414,
#     'acousticness': 0.908,
#     'instrumentalness': 0.000168,
#     'liveness': 0.107,
#     'valence': 0.778,
#     'tempo': 123.792,
#     'type': 'audio_features',
#     'id': '65jrjEhWfAvysKfnojk1i0',
#     'uri': 'spotify:track:65jrjEhWfAvysKfnojk1i0',
#     'track_href': 'https://api.spotify.com/v1/tracks/65jrjEhWfAvysKfnojk1i0',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/65jrjEhWfAvysKfnojk1i0',
#     'duration_ms': 161960,
#     'time_signature': 4}]},
#  {'Artist': 'Rockabye Baby!',
#   'Title': 'Under the Bridge',
#   'Album': 'Lullaby Renditions of Red Hot Chili Peppers',
#   'Audio Description': [{'danceability': 0.704,
#     'energy': 0.06,
#     'key': 4,
#     'loudness': -21.087,
#     'mode': 1,
#     'speechiness': 0.0907,
#     'acousticness': 0.946,
#     'instrumentalness': 0.912,
#     'liveness': 0.109,
#     'valence': 0.791,
#     'tempo': 158.085,
#     'type': 'audio_features',
#     'id': '45VCZtguiCNu5zJ3YkmcWC',
#     'uri': 'spotify:track:45VCZtguiCNu5zJ3YkmcWC',
#     'track_href': 'https://api.spotify.com/v1/tracks/45VCZtguiCNu5zJ3YkmcWC',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/45VCZtguiCNu5zJ3YkmcWC',
#     'duration_ms': 259693,
#     'time_signature': 4}]},
#  {'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'Greatest Hits',
#   'Audio Description': [{'danceability': 0.554,
#     'energy': 0.49,
#     'key': 4,
#     'loudness': -8.046,
#     'mode': 1,
#     'speechiness': 0.0457,
#     'acousticness': 0.0168,
#     'instrumentalness': 0.000534,
#     'liveness': 0.136,
#     'valence': 0.513,
#     'tempo': 84.275,
#     'type': 'audio_features',
#     'id': '23NPGXlSaIqWzvxIRhM2oG',
#     'uri': 'spotify:track:23NPGXlSaIqWzvxIRhM2oG',
#     'track_href': 'https://api.spotify.com/v1/tracks/23NPGXlSaIqWzvxIRhM2oG',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23NPGXlSaIqWzvxIRhM2oG',
#     'duration_ms': 265507,
#     'time_signature': 4}]},
#  {'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'Blood Sugar Sex Magik',
#   'Audio Description': [{'danceability': 0.559,
#     'energy': 0.345,
#     'key': 4,
#     'loudness': -13.496,
#     'mode': 1,
#     'speechiness': 0.0459,
#     'acousticness': 0.0576,
#     'instrumentalness': 0.000105,
#     'liveness': 0.141,
#     'valence': 0.458,
#     'tempo': 84.581,
#     'type': 'audio_features',
#     'id': '5PclxRY6shIQzSKxxbdZso',
#     'uri': 'spotify:track:5PclxRY6shIQzSKxxbdZso',
#     'track_href': 'https://api.spotify.com/v1/tracks/5PclxRY6shIQzSKxxbdZso',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PclxRY6shIQzSKxxbdZso',
#     'duration_ms': 264307,
#     'time_signature': 4}]},
#  {'Artist': 'Henry Smith',
#   'Title': 'Under the Bridge - Piano Version',
#   'Album': '90s Piano Covers (Vol. 1)',
#   'Audio Description': [{'danceability': 0.392,
#     'energy': 0.0226,
#     'key': 4,
#     'loudness': -24.691,
#     'mode': 1,
#     'speechiness': 0.0613,
#     'acousticness': 0.995,
#     'instrumentalness': 0.951,
#     'liveness': 0.0885,
#     'valence': 0.28,
#     'tempo': 75.726,
#     'type': 'audio_features',
#     'id': '7eIp7zGukxlcXr8IblOts8',
#     'uri': 'spotify:track:7eIp7zGukxlcXr8IblOts8',
#     'track_href': 'https://api.spotify.com/v1/tracks/7eIp7zGukxlcXr8IblOts8',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7eIp7zGukxlcXr8IblOts8',
#     'duration_ms': 195000,
#     'time_signature': 4}]}]

# %%
# Make a dataframe from the list of songs created in the function above.
df = pd.DataFrame(list_of_songs)

df
# Out:
#                   Artist                             Title  \
# 0  Red Hot Chili Peppers                  Under the Bridge
# 1                   owlh                  Under the Bridge
# 2                  Adele            Water Under the Bridge
# 3               Sam Hunt            Water Under The Bridge
# 4  Red Hot Chili Peppers                  Under the Bridge
# 5           The Drifters               Under the Boardwalk
# 6         Rockabye Baby!                  Under the Bridge
# 7  Red Hot Chili Peppers                  Under the Bridge
# 8  Red Hot Chili Peppers                  Under the Bridge
# 9            Henry Smith  Under the Bridge - Piano Version
#
#                                          Album  \
# 0       Blood Sugar Sex Magik (Deluxe Edition)
# 1                               cover to cover
# 2                                           25
# 3                       Water Under The Bridge
# 4      The Studio Album Collection 1991 - 2011
# 5                          Under the Boardwalk
# 6  Lullaby Renditions of Red Hot Chili Peppers
# 7                                Greatest Hits
# 8                        Blood Sugar Sex Magik
# 9                    90s Piano Covers (Vol. 1)
#
#                                    Audio Description
# 0  [{'danceability': 0.559, 'energy': 0.345, 'key...
# 1  [{'danceability': 0.781, 'energy': 0.355, 'key...
# 2  [{'danceability': 0.59, 'energy': 0.833, 'key'...
# 3  [{'danceability': 0.635, 'energy': 0.866, 'key...
# 4  [{'danceability': 0.554, 'energy': 0.49, 'key'...
# 5  [{'danceability': 0.747, 'energy': 0.226, 'key...
# 6  [{'danceability': 0.704, 'energy': 0.06, 'key'...
# 7  [{'danceability': 0.554, 'energy': 0.49, 'key'...
# 8  [{'danceability': 0.559, 'energy': 0.345, 'key...
# 9  [{'danceability': 0.392, 'energy': 0.0226, 'ke...

# %% [markdown]
# As you can see, this DataFrame looks a bit off as the audio descriptions aren't expanded - all of the data is clumped together in one cell. Let's correct this, so we can see each audio feature as an individual column.

# %%
# Quick function we can use to select only the first item.
# This can also be done simply with [0], but we wanted to show you how you can incorporate a custom function into your work.

def first_value (x):
    return x[0]

# Making a DataFrame from the audio features of the songs in list_of_songs.
df_audio_features = pd.json_normalize(df['Audio Description'].apply(first_value))

df_audio_features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.559  0.3450    4   -13.496     1       0.0459        0.0576
# 1         0.781  0.3550    9    -8.158     1       0.0376        0.4710
# 2         0.590  0.8330    5    -6.503     0       0.0615        0.0142
# 3         0.635  0.8660    5    -2.695     1       0.0473        0.0697
# 4         0.554  0.4900    4    -8.046     1       0.0457        0.0168
# 5         0.747  0.2260    7   -13.635     1       0.0414        0.9080
# 6         0.704  0.0600    4   -21.087     1       0.0907        0.9460
# 7         0.554  0.4900    4    -8.046     1       0.0457        0.0168
# 8         0.559  0.3450    4   -13.496     1       0.0459        0.0576
# 9         0.392  0.0226    4   -24.691     1       0.0613        0.9950
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000105    0.1410    0.458   84.581  audio_features
# 1          0.878000    0.1250    0.363  131.978  audio_features
# 2          0.000005    0.1050    0.538   94.963  audio_features
# 3          0.000000    0.0955    0.853  133.889  audio_features
# 4          0.000534    0.1360    0.513   84.275  audio_features
# 5          0.000168    0.1070    0.778  123.792  audio_features
# 6          0.912000    0.1090    0.791  158.085  audio_features
# 7          0.000534    0.1360    0.513   84.275  audio_features
# 8          0.000105    0.1410    0.458   84.581  audio_features
# 9          0.951000    0.0885    0.280   75.726  audio_features
#
#                        id                                   uri  \
# 0  3d9DChrdc6BOeFsbrZ3Is0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 1  1AyRpRvLwUwkXwGGuNZHmN  spotify:track:1AyRpRvLwUwkXwGGuNZHmN
# 2  4jL6WWKFDqCOPo2hC3VhSS  spotify:track:4jL6WWKFDqCOPo2hC3VhSS
# 3  4viFAHmivkYQKkwLvwKOgg  spotify:track:4viFAHmivkYQKkwLvwKOgg
# 4  1MMlmA1APa0MevW3Bm2PpE  spotify:track:1MMlmA1APa0MevW3Bm2PpE
# 5  65jrjEhWfAvysKfnojk1i0  spotify:track:65jrjEhWfAvysKfnojk1i0
# 6  45VCZtguiCNu5zJ3YkmcWC  spotify:track:45VCZtguiCNu5zJ3YkmcWC
# 7  23NPGXlSaIqWzvxIRhM2oG  spotify:track:23NPGXlSaIqWzvxIRhM2oG
# 8  5PclxRY6shIQzSKxxbdZso  spotify:track:5PclxRY6shIQzSKxxbdZso
# 9  7eIp7zGukxlcXr8IblOts8  spotify:track:7eIp7zGukxlcXr8IblOts8
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 1  https://api.spotify.com/v1/tracks/1AyRpRvLwUwk...
# 2  https://api.spotify.com/v1/tracks/4jL6WWKFDqCO...
# 3  https://api.spotify.com/v1/tracks/4viFAHmivkYQ...
# 4  https://api.spotify.com/v1/tracks/1MMlmA1APa0M...
# 5  https://api.spotify.com/v1/tracks/65jrjEhWfAvy...
# 6  https://api.spotify.com/v1/tracks/45VCZtguiCNu...
# 7  https://api.spotify.com/v1/tracks/23NPGXlSaIqW...
# 8  https://api.spotify.com/v1/tracks/5PclxRY6shIQ...
# 9  https://api.spotify.com/v1/tracks/7eIp7zGukxlc...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3d9D...       264307
# 1  https://api.spotify.com/v1/audio-analysis/1AyR...       244196
# 2  https://api.spotify.com/v1/audio-analysis/4jL6...       240439
# 3  https://api.spotify.com/v1/audio-analysis/4viF...       169760
# 4  https://api.spotify.com/v1/audio-analysis/1MMl...       265507
# 5  https://api.spotify.com/v1/audio-analysis/65jr...       161960
# 6  https://api.spotify.com/v1/audio-analysis/45VC...       259693
# 7  https://api.spotify.com/v1/audio-analysis/23NP...       265507
# 8  https://api.spotify.com/v1/audio-analysis/5Pcl...       264307
# 9  https://api.spotify.com/v1/audio-analysis/7eIp...       195000
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4

# %%
# Merge the expanded audio features with the original DataFrame.
new_df = pd.merge(df, df_audio_features, left_index=True, right_index=True)

# Drop the old ugly column where all the audio features are clumped together.
new_df.drop('Audio Description', axis=1, inplace=True)

new_df
# Out:
#                   Artist                             Title  \
# 0  Red Hot Chili Peppers                  Under the Bridge
# 1                   owlh                  Under the Bridge
# 2                  Adele            Water Under the Bridge
# 3               Sam Hunt            Water Under The Bridge
# 4  Red Hot Chili Peppers                  Under the Bridge
# 5           The Drifters               Under the Boardwalk
# 6         Rockabye Baby!                  Under the Bridge
# 7  Red Hot Chili Peppers                  Under the Bridge
# 8  Red Hot Chili Peppers                  Under the Bridge
# 9            Henry Smith  Under the Bridge - Piano Version
#
#                                          Album  danceability  energy  key  \
# 0       Blood Sugar Sex Magik (Deluxe Edition)         0.559  0.3450    4
# 1                               cover to cover         0.781  0.3550    9
# 2                                           25         0.590  0.8330    5
# 3                       Water Under The Bridge         0.635  0.8660    5
# 4      The Studio Album Collection 1991 - 2011         0.554  0.4900    4
# 5                          Under the Boardwalk         0.747  0.2260    7
# 6  Lullaby Renditions of Red Hot Chili Peppers         0.704  0.0600    4
# 7                                Greatest Hits         0.554  0.4900    4
# 8                        Blood Sugar Sex Magik         0.559  0.3450    4
# 9                    90s Piano Covers (Vol. 1)         0.392  0.0226    4
#
#    loudness  mode  speechiness  acousticness  ...  liveness  valence    tempo  \
# 0   -13.496     1       0.0459        0.0576  ...    0.1410    0.458   84.581
# 1    -8.158     1       0.0376        0.4710  ...    0.1250    0.363  131.978
# 2    -6.503     0       0.0615        0.0142  ...    0.1050    0.538   94.963
# 3    -2.695     1       0.0473        0.0697  ...    0.0955    0.853  133.889
# 4    -8.046     1       0.0457        0.0168  ...    0.1360    0.513   84.275
# 5   -13.635     1       0.0414        0.9080  ...    0.1070    0.778  123.792
# 6   -21.087     1       0.0907        0.9460  ...    0.1090    0.791  158.085
# 7    -8.046     1       0.0457        0.0168  ...    0.1360    0.513   84.275
# 8   -13.496     1       0.0459        0.0576  ...    0.1410    0.458   84.581
# 9   -24.691     1       0.0613        0.9950  ...    0.0885    0.280   75.726
#
#              type                      id  \
# 0  audio_features  3d9DChrdc6BOeFsbrZ3Is0
# 1  audio_features  1AyRpRvLwUwkXwGGuNZHmN
# 2  audio_features  4jL6WWKFDqCOPo2hC3VhSS
# 3  audio_features  4viFAHmivkYQKkwLvwKOgg
# 4  audio_features  1MMlmA1APa0MevW3Bm2PpE
# 5  audio_features  65jrjEhWfAvysKfnojk1i0
# 6  audio_features  45VCZtguiCNu5zJ3YkmcWC
# 7  audio_features  23NPGXlSaIqWzvxIRhM2oG
# 8  audio_features  5PclxRY6shIQzSKxxbdZso
# 9  audio_features  7eIp7zGukxlcXr8IblOts8
#
#                                     uri  \
# 0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 1  spotify:track:1AyRpRvLwUwkXwGGuNZHmN
# 2  spotify:track:4jL6WWKFDqCOPo2hC3VhSS
# 3  spotify:track:4viFAHmivkYQKkwLvwKOgg
# 4  spotify:track:1MMlmA1APa0MevW3Bm2PpE
# 5  spotify:track:65jrjEhWfAvysKfnojk1i0
# 6  spotify:track:45VCZtguiCNu5zJ3YkmcWC
# 7  spotify:track:23NPGXlSaIqWzvxIRhM2oG
# 8  spotify:track:5PclxRY6shIQzSKxxbdZso
# 9  spotify:track:7eIp7zGukxlcXr8IblOts8
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 1  https://api.spotify.com/v1/tracks/1AyRpRvLwUwk...
# 2  https://api.spotify.com/v1/tracks/4jL6WWKFDqCO...
# 3  https://api.spotify.com/v1/tracks/4viFAHmivkYQ...
# 4  https://api.spotify.com/v1/tracks/1MMlmA1APa0M...
# 5  https://api.spotify.com/v1/tracks/65jrjEhWfAvy...
# 6  https://api.spotify.com/v1/tracks/45VCZtguiCNu...
# 7  https://api.spotify.com/v1/tracks/23NPGXlSaIqW...
# 8  https://api.spotify.com/v1/tracks/5PclxRY6shIQ...
# 9  https://api.spotify.com/v1/tracks/7eIp7zGukxlc...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3d9D...      264307
# 1  https://api.spotify.com/v1/audio-analysis/1AyR...      244196
# 2  https://api.spotify.com/v1/audio-analysis/4jL6...      240439
# 3  https://api.spotify.com/v1/audio-analysis/4viF...      169760
# 4  https://api.spotify.com/v1/audio-analysis/1MMl...      265507
# 5  https://api.spotify.com/v1/audio-analysis/65jr...      161960
# 6  https://api.spotify.com/v1/audio-analysis/45VC...      259693
# 7  https://api.spotify.com/v1/audio-analysis/23NP...      265507
# 8  https://api.spotify.com/v1/audio-analysis/5Pcl...      264307
# 9  https://api.spotify.com/v1/audio-analysis/7eIp...      195000
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
#
# [10 rows x 21 columns]

# %% [markdown]
# If you like a challenge and want to have a go at testing what you've just learned: Follow the steps below and see if you can make a DataFrame similar to the one above with expanded audio features. This time though, do it for a playlist of your choice on spotify. Then see if you can expand it to include the songs from multiple playlists.
#
# Try not to look at the solution, but we've included it below in case you get stuck
#
# ### Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have to be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %%
# your code here

# %% [markdown]
# #### Solution

# %%
list_of_playlists = ["spotify:playlist:2zjepkjZxLpeIBlvPCWIHl",
                    "spotify:playlist:0ce6Rmxf7QXroqa1wzjWY8"]

track_list = []
for i in list_of_playlists:
    individual_playlist = sp.user_playlist_tracks(user="spotify", playlist_id=i)['items']
    for j in individual_playlist:
        track_dict = {}
        track_dict['Artist'] = j['track']['artists'][0]['name']
        track_dict['Title'] = j['track']['name']
        track_dict['Album'] = j['track']['album']['name']
        track_dict['Audio Description'] = sp.audio_features(j['track']['id'])
        track_list.append(track_dict)

print(track_list)
# Out:
# [{'Artist': 'James Blake', 'Title': 'Words That We Both Know', 'Album': '200 Press EP', 'Audio Description': [{'danceability': 0.5, 'energy': 0.439, 'key': 7, 'loudness': -9.207, 'mode': 0, 'speechiness': 0.107, 'acousticness': 0.927, 'instrumentalness': 0.000445, 'liveness': 0.281, 'valence': 0.42, 'tempo': 62.058, 'type': 'audio_features', 'id': '4BZtAKMwi4aM18Zr2mTIgt', 'uri': 'spotify:track:4BZtAKMwi4aM18Zr2mTIgt', 'track_href': 'https://api.spotify.com/v1/tracks/4BZtAKMwi4aM18Zr2mTIgt', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4BZtAKMwi4aM18Zr2mTIgt', 'duration_ms': 63025, 'time_signature': 5}]}, {'Artist': 'Gene Wilder', 'Title': 'Pure Imagination - From "Willy Wonka & The Chocolate Factory" Soundtrack', 'Album': 'Willy Wonka & The Chocolate Factory', 'Audio Description': [{'danceability': 0.251, 'energy': 0.115, 'key': 10, 'loudness': -20.223, 'mode': 0, 'speechiness': 0.038, 'acousticness': 0.695, 'instrumentalness': 2.11e-05, 'liveness': 0.617, 'valence': 0.116, 'tempo': 70.645, 'type': 'audio_features', 'id': '4f4HLo6L9CJNhD4mEYxrCL', 'uri': 'spotify:track:4f4HLo6L9CJNhD4mEYxrCL', 'track_href': 'https://api.spotify.com/v1/tracks/4f4HLo6L9CJNhD4mEYxrCL', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4f4HLo6L9CJNhD4mEYxrCL', 'duration_ms': 260227, 'time_signature': 4}]}, {'Artist': 'Bob Dorough', 'Title': 'Polka Dots and Moonbeams', 'Album': 'Devil May Care', 'Audio Description': [{'danceability': 0.58, 'energy': 0.133, 'key': 0, 'loudness': -18.177, 'mode': 0, 'speechiness': 0.0962, 'acousticness': 0.795, 'instrumentalness': 0.0172, 'liveness': 0.18, 'valence': 0.211, 'tempo': 57.658, 'type': 'audio_features', 'id': '2wy2ScXvlpguDeo4NnwvOm', 'uri': 'spotify:track:2wy2ScXvlpguDeo4NnwvOm', 'track_href': 'https://api.spotify.com/v1/tracks/2wy2ScXvlpguDeo4NnwvOm', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2wy2ScXvlpguDeo4NnwvOm', 'duration_ms': 205360, 'time_signature': 3}]}, {'Artist': 'Isaiah Rashad', 'Title': 'R.I.P. Kevin Miller', 'Album': 'Cilvia Demo', 'Audio Description': [{'danceability': 0.703, 'energy': 0.835, 'key': 8, 'loudness': -4.456, 'mode': 0, 'speechiness': 0.27, 'acousticness': 0.227, 'instrumentalness': 1.4e-05, 'liveness': 0.135, 'valence': 0.602, 'tempo': 136.158, 'type': 'audio_features', 'id': '6zSwnPvoqQ2bzvYMlt3u4u', 'uri': 'spotify:track:6zSwnPvoqQ2bzvYMlt3u4u', 'track_href': 'https://api.spotify.com/v1/tracks/6zSwnPvoqQ2bzvYMlt3u4u', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6zSwnPvoqQ2bzvYMlt3u4u', 'duration_ms': 229219, 'time_signature': 4}]}, {'Artist': 'Jon Brion', 'Title': 'Phone Call - From "Eternal Sunshine of the Spotless Mind"/Score', 'Album': 'Eternal Sunshine Of The Spotless Mind', 'Audio Description': [{'danceability': 0.498, 'energy': 0.377, 'key': 1, 'loudness': -19.858, 'mode': 1, 'speechiness': 0.0474, 'acousticness': 0.982, 'instrumentalness': 0.938, 'liveness': 0.107, 'valence': 0.545, 'tempo': 126.252, 'type': 'audio_features', 'id': '7LYeytL8R2fuqnsW1s0k86', 'uri': 'spotify:track:7LYeytL8R2fuqnsW1s0k86', 'track_href': 'https://api.spotify.com/v1/tracks/7LYeytL8R2fuqnsW1s0k86', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LYeytL8R2fuqnsW1s0k86', 'duration_ms': 62600, 'time_signature': 4}]}, {'Artist': 'Action Bronson', 'Title': 'Terry', 'Album': 'Mr. Wonderful', 'Audio Description': [{'danceability': 0.376, 'energy': 0.62, 'key': 1, 'loudness': -5.84, 'mode': 1, 'speechiness': 0.367, 'acousticness': 0.707, 'instrumentalness': 0, 'liveness': 0.107, 'valence': 0.0477, 'tempo': 87.538, 'type': 'audio_features', 'id': '6bj42Hzr3RErxhfgSTdSx6', 'uri': 'spotify:track:6bj42Hzr3RErxhfgSTdSx6', 'track_href': 'https://api.spotify.com/v1/tracks/6bj42Hzr3RErxhfgSTdSx6', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6bj42Hzr3RErxhfgSTdSx6', 'duration_ms': 289493, 'time_signature': 4}]}, {'Artist': 'Benny Sings', 'Title': 'Realize', 'Album': 'Art', 'Audio Description': [{'danceability': 0.829, 'ene ...

# %%
playlist_df = pd.DataFrame(track_list)

# %%
df_a_f = pd.json_normalize(playlist_df['Audio Description'].apply(first_value))

# %%
new_playlist_df = pd.merge(playlist_df, df_a_f, left_index=True, right_index=True)

# %%
new_playlist_df.drop('Audio Description', axis=1, inplace=True)

# %%
new_playlist_df
# Out:
#                       Artist  \
# 0                James Blake
# 1                Gene Wilder
# 2                Bob Dorough
# 3              Isaiah Rashad
# 4                  Jon Brion
# 5             Action Bronson
# 6                Benny Sings
# 7      Oneohtrix Point Never
# 8                 Pink Floyd
# 9           Boards of Canada
# 10                   J Dilla
# 11              Flying Lotus
# 12                   Pusha T
# 13               The Beatles
# 14                     Wilco
# 15              Akron/Family
# 16  The Mothers Of Invention
# 17           Daniel Johnston
# 18                 BUSDRIVER
# 19                Kanye West
# 20                  Bill Fay
# 21           Gil Scott-Heron
# 22                 Bob Dylan
# 23                      Edan
# 24            Kendrick Lamar
# 25           Daniel Johnston
# 26            Anderson .Paak
# 27           Thelonious Monk
# 28              Quelle Chris
# 29                     JAY-Z
# 30                   Pusha T
# 31            The Beach Boys
# 32             Dexter Wansel
# 33                       Yes
# 34            Taylor Deupree
# 35             Vince Staples
# 36                 Radiohead
# 37       There Will Be Blood
# 38                Tim Hecker
# 39             Billy Collins
# 40                 S+C+A+R+R
# 41      Manchester Orchestra
# 42           Nina & Frederik
# 43           Kid Francescoli
# 44                   Caribou
# 45                 Manu Chao
# 46       Cannonball Adderley
# 47           Jacques Dutronc
# 48           Floating Points
# 49            The Dead South
# 50      Antônio Carlos Jobim
# 51                    Tiësto
# 52             Johnny Hooker
# 53        The Tragically Hip
# 54        Family of the Year
# 55       Maverick City Music
#
#                                                 Title  \
# 0                             Words That We Both Know
# 1   Pure Imagination - From "Willy Wonka & The Cho...
# 2                            Polka Dots and Moonbeams
# 3                                 R.I.P. Kevin Miller
# 4   Phone Call - From "Eternal Sunshine of the Spo...
# 5                                               Terry
# 6                                             Realize
# 7                                        Sleep Dealer
# 8                              Welcome to the Machine
# 9                                         Dawn Chorus
# 10                                         Make'em NV
# 11                            Coronus, the Terminator
# 12                                             M.P.A.
# 13     You Never Give Me Your Money - Remastered 2009
# 14                    I Am Trying to Break Your Heart
# 15                                              Italy
# 16                                   Are You Hung Up?
# 17                       Some Things Last A Long Time
# 18      Worlds to Run (featuring Milo, Anderson Paak)
# 19                                       Real Friends
# 20                             Never Ending Happening
# 21                                       I’m New Here
# 22                       It's All Over Now, Baby Blue
# 23                                             Beauty
# 24                 Sing About Me, I'm Dying Of Thirst
# 25                                   My Yoke Is Heavy
# 26       Room in Here (feat. The Game & Sonyae Elise)
# 27                                    'Round Midnight
# 28  Greene Eyes f. (Tanya Morgan, Cavalier, Fresh ...
# 29                                             Versus
# 30                             Drug Dealers Anonymous
# 31                      Little Bird - Remastered 2001
# 32                                Together Once Again
# 33                                Yesterday and Today
# 34                                               Bell
# 35                                         Summertime
# 36                                    True Love Waits
# 37                                 Prospectors Arrive
# 38                           I'm Transmitting Tonight
# 39                                      forgetfulness
# 40             You're the One - From "I Lost My Body"
# 41                                          The Alien
# 42                        Oh, Pecador (Oh, Sinne Man)
# 43                            Moon (And It Went Like)
# 44                                    Never Come Back
# 45                                    Trapped By Love
# 46                                Mercy, Mercy, Mercy
# 47                                     Le responsable
# 48                                               Bias
# 49                    In Hell I'll Be in Good Company
# 50                                      Água De Beber
# 51                                       The Business
# 52                                      Amor Marginal
# 53                                 Ahead By A Century
# 54                                               Hero
# 55                                           Promises
#
#                                                 Album  danceability  energy  \
# 0                                        200 Press EP         0.500   0.439
# 1                 Willy Wonka & The Chocolate Factory         0.251   0.115
# 2                                      Devil May Care         0.580   0.133
# 3                                         Cilvia Demo         0.703   0.835
# 4               Eternal Sunshine Of The Spotless Mind         0.498   0.377
# 5                                       Mr. Wonderful         0.376   0.620
# 6                                                 Art         0.829   0.237
# 7                                             Replica         0.587   0.782
# 8                                  Wish You Were Here         0.381   0.358
# 9                                            Geogaddi         0.418   0.686
# 10                                         Ruff Draft         0.740   0.907
# 11                                       You're Dead!         0.438   0.529
# 12       King Push – Darkest Before Dawn: The Prelude         0.518   0.619
# 13                            Abbey Road (Remastered)         0.335   0.416
# 14                               Yankee Hotel Foxtrot         0.467   0.536
# 15                                       Akron/Family         0.422   0.371
# 16                     We're Only In It For The Money         0.516   0.417
# 17                                               1990         0.502   0.114
# 18                                             Thumbs         0.614   0.671
# 19                                  The Life Of Pablo         0.441   0.744
# 20                                     Life Is People         0.566   0.232
# 21                                       I’m New Here         0.362   0.217
# 22                          Bringing It All Back Home         0.699   0.197
# 23                                  Beauty & The Beat         0.527   0.949
# 24                    good kid, m.A.A.d city (Deluxe)         0.654   0.753
# 25                                    Don't Be Scared         0.471   0.601
# 26                                             Malibu         0.643   0.894
# 27   Genius Of Modern Music (Vol.1, Expanded Edition)         0.542   0.320
# 28                                      Ni**as Is Men         0.730   0.674
# 29                          Magna Carta... Holy Grail         0.852   0.877
# 30                             Drug Dealers Anonymous         0.558   0.864
# 31                               Friends (Remastered)         0.452   0.330
# 32                                       Life on Mars         0.371   0.381
# 33                                                Yes         0.485   0.179
# 34                                              Twine         0.198   0.255
# 35                                     Summertime '06         0.446   0.593
# 36                                 A Moon Shaped Pool         0.282   0.132
# 37                                There Will Be Blood         0.145   0.179
# 38                                         Radio Amor         0.190   0.388
# 39                                 The Best Cigarette         0.618   0.298
# 40             You're the One (From "I Lost My Body")         0.535   0.724
# 41                        A Black Mile To The Surface         0.464   0.334
# 42  Vintage World Nº10- EPs Collectors "Oh, Pecado...         0.623   0.239
# 43                                      Play Me Again         0.662   0.657
# 44                                    Never Come Back         0.776   0.684
# 45                       Proxima Estacion : Esperanza         0.735   0.743
# 46                  Jazz Profile: Cannonball Adderley         0.544   0.425
# 47                                      L' aventurier         0.684   0.825
# 48                                              Crush         0.601   0.476
# 49                                       Good Company         0.766   0.233
# 50                               Antonio Carlos Jobim         0.650   0.421
# 51                                       The Business         0.798   0.620
# 52  Eu Vou Fazer uma Macumba Pra Te Amarrar, Maldito!         0.423   0.539
# 53                                     Yer Favourites         0.778   0.628
# 54                                         Loma Vista         0.341   0.539
# 55                        Maverick City Vol. 3 Part 1         0.361   0.423
#
#     key  loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0     7    -9.207     0       0.1070       0.92700  ...    0.2810   0.4200
# 1    10   -20.223     0       0.0380       0.69500  ...    0.6170   0.1160
# 2     0   -18.177     0       0.0962       0.79500  ...    0.1800   0.2110
# 3     8    -4.456     0       0.2700       0.22700  ...    0.1350   0.6020
# 4     1   -19.858     1       0.0474       0.98200  ...    0.1070   0.5450
# 5     1    -5.840     1       0.3670       0.70700  ...    0.1070   0.0477
# 6     1    -9.388     1       0.1130       0.48200  ...    0.0987   0.8070
# 7    10    -9.733     0       0.0837       0.64000  ...    0.6080   0.2730
# 8     0   -12.423     1       0.0365       0.52400  ...    0.0747   0.0360
# 9     5    -8.658     1       0.0350       0.00177  ...    0.8630   0.5470
# 10   11    -7.687     1       0.1640       0.00980  ...    0.1690   0.6070
# 11    2    -6.158     0       0.0355       0.19000  ...    0.1380   0.2940
# 12    2    -9.241     0       0.4560       0.31300  ...    0.3130   0.3340
# 13    0   -11.051     1       0.0348       0.34500  ...    0.1160   0.2230
# 14    4   -10.906     1       0.0268       0.31700  ...    0.1230   0.4290
# 15    4    -7.636     1       0.0558       0.31900  ...    0.7960   0.1540
# 16    9   -17.412     1       0.8800       0.51800  ...    0.1860   0.2330
# 17    0   -12.963     1       0.0366       0.96100  ...    0.1240   0.2210
# 18    4    -8.029     0       0.1470       0.13600  ...    0.1700   0.2140
# 19    6    -6.248     0       0.4760       0.26200  ...    0.1380   0.1240
# 20   11   -14.234     1       0.0321       0.91100  ...    0.1180   0.1680
# 21    6   -13.645     1       0.0366       0.90700  ...    0.1150   0.3040
# 22    4   -14.792     1       0.0383       0.65500  ...    0.0716   0.3610
# 23    9    -6.750     1       0.5080       0.59700  ...    0.2350   0.3660
# 24   11    -7.556     0       0.3950       0.30300  ...    0.1300   0.3710
# 25    0    -9.504     1       0.1950       0.98100  ...    0.2240   0.5560
# 26    6    -4.765     0       0.3740       0.26900  ...    0.2570   0.4590
# 27    8    -9.975     1       0.0387       0.90700  ...    0.0609   0.2060
# 28    1    -7.952     0       0.3700       0.51200  ...    0.4560   0.6440
# 29    4    -5.955     0       0.2330       0.05650  ...    0.1640   0.8020
# 30   11    -5.100     1       0.4300       0.31800  ...    0.1230   0.4740
# 31    5   -10.376     1       0.0384       0.12100  ...    0.0978   0.1970
# 32    5    -9.780     1       0.0289       0.77200  ...    0.1590   0.1670
# 33    4   -16.377     1       0.0303       0.85900  ...    0.1180   0.2350
# 34    2   -20.479     1       0.0405       0.88400  ...    0.0899   0.0388
# 35   11    -7.748     1       0.0597       0.03650  ...    0.0988   0.0706
# 36    0   -15.569     1       0.0375       0.93800  ...    0.1000   0.0379
# 37    5   -18.168     0       0.0386       0.94900  ...    0.1660   0.0338
# 38    0   -19.922     0       0.0587       0.97600  ...    0.6660   0.0615
# 39   11   -17.386     1       0.9370       0.97700  ...    0.6370   0.3970
# 40    5    -9.905     1       0.0618       0.20200  ...    0.0983   0.3700
# 41    6   -12.916     1       0.0313       0.30700  ...    0.1100   0.3260
# 42   11   -12.638     0       0.0979       0.88600  ...    0.1710   0.5850
# 43    7   -10.002     1       0.0345       0.28800  ...    0.1020   0.0584
# 44    5    -8.934     1       0.0367       0.40500  ...    0.0663   0.6550
# 45    0    -7.809     0       0.0453       0.13800  ...    0.4830   0.7000
# 46   10   -10.231     1       0.0346       0.71900  ...    0.9640   0.3480
# 47    9    -7.241     1       0.0724       0.01420  ...    0.0722   0.9600
# 48    1   -12.026     0       0.0761       0.06630  ...    0.1170   0.1860
# 49    7    -9.086     0       0.0487       0.75700  ...    0.1110   0.7360
# 50    9   -11.384     1       0.0360       0.74600  ...    0.3360   0.7000
# 51    8    -7.079     0       0.2320       0.41400  ...    0.1120   0.2350
# 52    9    -5.722     0       0.0368       0.25200  ...    0.0959   0.1960
# 53    7    -7.306     1       0.0275       0.01640  ...    0.0862   0.3560
# 54    5    -5.760     1       0.0265       0.21300  ...    0.1090   0.2670
# 55   10   -11.697     1       0.0375       0.28300  ...    0.0942   0.2380
#
#       tempo            type                      id  \
# 0    62.058  audio_features  4BZtAKMwi4aM18Zr2mTIgt
# 1    70.645  audio_features  4f4HLo6L9CJNhD4mEYxrCL
# 2    57.658  audio_features  2wy2ScXvlpguDeo4NnwvOm
# 3   136.158  audio_features  6zSwnPvoqQ2bzvYMlt3u4u
# 4   126.252  audio_features  7LYeytL8R2fuqnsW1s0k86
# 5    87.538  audio_features  6bj42Hzr3RErxhfgSTdSx6
# 6    75.512  audio_features  6HKq2PtG1X7f5QaVBlGTGr
# 7   112.159  audio_features  5KXSZjxPDUHJUGfVExhOEh
# 8   133.271  audio_features  5VWC7v2dC2K0SIIjT9WTLN
# 9    75.241  audio_features  7LY0R33pPIFr0Y64VZC9Wo
# 10   93.880  audio_features  4eES0u2J5rYU2qrO7KyFCU
# 11   79.929  audio_features  79gyBvPc2zj3oIrhI50Eag
# 12  168.591  audio_features  09W3YKEDiMFsX7QxWJm2zX
# 13  174.464  audio_features  1jOLTO379yIu9aMnCkpMQl
# 14   85.958  audio_features  3HWxpLKnTlz6jE3Vi5dTF2
# 15  113.598  audio_features  4tc1ZjeJVDNazYsU9m3Un7
# 16   82.550  audio_features  2hJRFLEbOtOTMiLkrgeioZ
# 17   79.046  audio_features  4ndBp2Mm0oBNOdjyQvJ9jz
# 18  143.099  audio_features  59jz14e2H1EkNHiXY7kd05
# 19   81.396  audio_features  66Q3fAmSX5eHamgbKa9alP
# 20  107.896  audio_features  6G4kaenlQc9IV4neoUknlI
# 21  152.303  audio_features  1VHYY5d9T19SwziU6uY4AE
# 22  122.871  audio_features  4EgKcG7aswxVfQEqa3dl8S
# 23   93.289  audio_features  6NH8vSRKDENrH5WzUileEB
# 24  110.722  audio_features  3q2v8QaTnHLveAQzR6gvYm
# 25  122.683  audio_features  5eCzKVQirjbJxZJdbrxeiF
# 26   86.985  audio_features  6Lr9sGM6kARYVDL2dj0lqV
# 27  116.648  audio_features  1wl5b2lw3YagQtZiYZbQWP
# 28   81.104  audio_features  0h2lSuq07PRjQ6jCYB7hu3
# 29   79.370  audio_features  2rhS1u6ckiW3fSslPn5V3A
# 30  152.804  audio_features  1b6rmL3VXBgYTbn61kM8wT
# 31  164.890  audio_features  0EhhRq90FVkx8Rv1vzZUOG
# 32  130.920  audio_features  1VjlyIUh31hgMfNOjC7ZcD
# 33   75.346  audio_features  37PSl0SD25vE0hFEJxpRir
# 34   95.560  audio_features  2BQpTDZOXHYyWkGZUTmvNl
# 35  123.884  audio_features  7GKiBHjFfvPRNqqOuRYqLB
# 36  136.186  audio_features  01ZpFhrMMqKPVCwyqXneVp
# 37   66.062  audio_features  5gHu56UXELp87jYIpauO75
# 38  129.993  audio_features  0eztk0w79uHB0RCXUYQ7Ao
# 39  106.934  audio_features  4Lgi4kxKHosBEe26fIoPwU
# 40  159.948  audio_features  5Tnx4R7Gwj1LZsfssfzchh
# 41  165.278  audio_features  5eKfpH2dQ7FltCqb7LWEGJ
# 42  124.485  audio_features  0R3OcHrzq3f8raukyZgTAc
# 43  117.986  audio_features  24upABZ8A0sAepfu91sEYr
# 44  127.979  audio_features  7IBrKDuBlyz3vW9JFCux10
# 45   98.971  audio_features  3ecVMxkn0sJ3nlx1uS0IVN
# 46   84.443  audio_features  6NF8MZ2trxckVBr82pyyPt
# 47  139.807  audio_features  6FwkZ5lYdCUh1mzI1Bhojn
# 48  145.997  audio_features  75QdM3nsnAluOD19G1J4il
# 49  154.716  audio_features  6Yg3gGtLuZTyZ8i4zGUaJa
# 50  136.931  audio_features  03XkLBYaV5PlgHQYlTEvZm
# 51  120.031  audio_features  6f3Slt0GbA2bPZlz0aIFXN
# 52  170.510  audio_features  7uSdpAkxgB0948bW7yjjJO
# 53  126.586  audio_features  5nC2BQzszGGkZi7cvxFzH4
# 54  174.564  audio_features  6GRDI9suQHikFP6euIXnpq
# 55  114.660  audio_features  0aZFEiDKLK2B4gzPaGCZVm
#
#                                      uri  \
# 0   spotify:track:4BZtAKMwi4aM18Zr2mTIgt
# 1   spotify:track:4f4HLo6L9CJNhD4mEYxrCL
# 2   spotify:track:2wy2ScXvlpguDeo4NnwvOm
# 3   spotify:track:6zSwnPvoqQ2bzvYMlt3u4u
# 4   spotify:track:7LYeytL8R2fuqnsW1s0k86
# 5   spotify:track:6bj42Hzr3RErxhfgSTdSx6
# 6   spotify:track:6HKq2PtG1X7f5QaVBlGTGr
# 7   spotify:track:5KXSZjxPDUHJUGfVExhOEh
# 8   spotify:track:5VWC7v2dC2K0SIIjT9WTLN
# 9   spotify:track:7LY0R33pPIFr0Y64VZC9Wo
# 10  spotify:track:4eES0u2J5rYU2qrO7KyFCU
# 11  spotify:track:79gyBvPc2zj3oIrhI50Eag
# 12  spotify:track:09W3YKEDiMFsX7QxWJm2zX
# 13  spotify:track:1jOLTO379yIu9aMnCkpMQl
# 14  spotify:track:3HWxpLKnTlz6jE3Vi5dTF2
# 15  spotify:track:4tc1ZjeJVDNazYsU9m3Un7
# 16  spotify:track:2hJRFLEbOtOTMiLkrgeioZ
# 17  spotify:track:4ndBp2Mm0oBNOdjyQvJ9jz
# 18  spotify:track:59jz14e2H1EkNHiXY7kd05
# 19  spotify:track:66Q3fAmSX5eHamgbKa9alP
# 20  spotify:track:6G4kaenlQc9IV4neoUknlI
# 21  spotify:track:1VHYY5d9T19SwziU6uY4AE
# 22  spotify:track:4EgKcG7aswxVfQEqa3dl8S
# 23  spotify:track:6NH8vSRKDENrH5WzUileEB
# 24  spotify:track:3q2v8QaTnHLveAQzR6gvYm
# 25  spotify:track:5eCzKVQirjbJxZJdbrxeiF
# 26  spotify:track:6Lr9sGM6kARYVDL2dj0lqV
# 27  spotify:track:1wl5b2lw3YagQtZiYZbQWP
# 28  spotify:track:0h2lSuq07PRjQ6jCYB7hu3
# 29  spotify:track:2rhS1u6ckiW3fSslPn5V3A
# 30  spotify:track:1b6rmL3VXBgYTbn61kM8wT
# 31  spotify:track:0EhhRq90FVkx8Rv1vzZUOG
# 32  spotify:track:1VjlyIUh31hgMfNOjC7ZcD
# 33  spotify:track:37PSl0SD25vE0hFEJxpRir
# 34  spotify:track:2BQpTDZOXHYyWkGZUTmvNl
# 35  spotify:track:7GKiBHjFfvPRNqqOuRYqLB
# 36  spotify:track:01ZpFhrMMqKPVCwyqXneVp
# 37  spotify:track:5gHu56UXELp87jYIpauO75
# 38  spotify:track:0eztk0w79uHB0RCXUYQ7Ao
# 39  spotify:track:4Lgi4kxKHosBEe26fIoPwU
# 40  spotify:track:5Tnx4R7Gwj1LZsfssfzchh
# 41  spotify:track:5eKfpH2dQ7FltCqb7LWEGJ
# 42  spotify:track:0R3OcHrzq3f8raukyZgTAc
# 43  spotify:track:24upABZ8A0sAepfu91sEYr
# 44  spotify:track:7IBrKDuBlyz3vW9JFCux10
# 45  spotify:track:3ecVMxkn0sJ3nlx1uS0IVN
# 46  spotify:track:6NF8MZ2trxckVBr82pyyPt
# 47  spotify:track:6FwkZ5lYdCUh1mzI1Bhojn
# 48  spotify:track:75QdM3nsnAluOD19G1J4il
# 49  spotify:track:6Yg3gGtLuZTyZ8i4zGUaJa
# 50  spotify:track:03XkLBYaV5PlgHQYlTEvZm
# 51  spotify:track:6f3Slt0GbA2bPZlz0aIFXN
# 52  spotify:track:7uSdpAkxgB0948bW7yjjJO
# 53  spotify:track:5nC2BQzszGGkZi7cvxFzH4
# 54  spotify:track:6GRDI9suQHikFP6euIXnpq
# 55  spotify:track:0aZFEiDKLK2B4gzPaGCZVm
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4BZtAKMwi4aM...
# 1   https://api.spotify.com/v1/tracks/4f4HLo6L9CJN...
# 2   https://api.spotify.com/v1/tracks/2wy2ScXvlpgu...
# 3   https://api.spotify.com/v1/tracks/6zSwnPvoqQ2b...
# 4   https://api.spotify.com/v1/tracks/7LYeytL8R2fu...
# 5   https://api.spotify.com/v1/tracks/6bj42Hzr3REr...
# 6   https://api.spotify.com/v1/tracks/6HKq2PtG1X7f...
# 7   https://api.spotify.com/v1/tracks/5KXSZjxPDUHJ...
# 8   https://api.spotify.com/v1/tracks/5VWC7v2dC2K0...
# 9   https://api.spotify.com/v1/tracks/7LY0R33pPIFr...
# 10  https://api.spotify.com/v1/tracks/4eES0u2J5rYU...
# 11  https://api.spotify.com/v1/tracks/79gyBvPc2zj3...
# 12  https://api.spotify.com/v1/tracks/09W3YKEDiMFs...
# 13  https://api.spotify.com/v1/tracks/1jOLTO379yIu...
# 14  https://api.spotify.com/v1/tracks/3HWxpLKnTlz6...
# 15  https://api.spotify.com/v1/tracks/4tc1ZjeJVDNa...
# 16  https://api.spotify.com/v1/tracks/2hJRFLEbOtOT...
# 17  https://api.spotify.com/v1/tracks/4ndBp2Mm0oBN...
# 18  https://api.spotify.com/v1/tracks/59jz14e2H1Ek...
# 19  https://api.spotify.com/v1/tracks/66Q3fAmSX5eH...
# 20  https://api.spotify.com/v1/tracks/6G4kaenlQc9I...
# 21  https://api.spotify.com/v1/tracks/1VHYY5d9T19S...
# 22  https://api.spotify.com/v1/tracks/4EgKcG7aswxV...
# 23  https://api.spotify.com/v1/tracks/6NH8vSRKDENr...
# 24  https://api.spotify.com/v1/tracks/3q2v8QaTnHLv...
# 25  https://api.spotify.com/v1/tracks/5eCzKVQirjbJ...
# 26  https://api.spotify.com/v1/tracks/6Lr9sGM6kARY...
# 27  https://api.spotify.com/v1/tracks/1wl5b2lw3Yag...
# 28  https://api.spotify.com/v1/tracks/0h2lSuq07PRj...
# 29  https://api.spotify.com/v1/tracks/2rhS1u6ckiW3...
# 30  https://api.spotify.com/v1/tracks/1b6rmL3VXBgY...
# 31  https://api.spotify.com/v1/tracks/0EhhRq90FVkx...
# 32  https://api.spotify.com/v1/tracks/1VjlyIUh31hg...
# 33  https://api.spotify.com/v1/tracks/37PSl0SD25vE...
# 34  https://api.spotify.com/v1/tracks/2BQpTDZOXHYy...
# 35  https://api.spotify.com/v1/tracks/7GKiBHjFfvPR...
# 36  https://api.spotify.com/v1/tracks/01ZpFhrMMqKP...
# 37  https://api.spotify.com/v1/tracks/5gHu56UXELp8...
# 38  https://api.spotify.com/v1/tracks/0eztk0w79uHB...
# 39  https://api.spotify.com/v1/tracks/4Lgi4kxKHosB...
# 40  https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1L...
# 41  https://api.spotify.com/v1/tracks/5eKfpH2dQ7Fl...
# 42  https://api.spotify.com/v1/tracks/0R3OcHrzq3f8...
# 43  https://api.spotify.com/v1/tracks/24upABZ8A0sA...
# 44  https://api.spotify.com/v1/tracks/7IBrKDuBlyz3...
# 45  https://api.spotify.com/v1/tracks/3ecVMxkn0sJ3...
# 46  https://api.spotify.com/v1/tracks/6NF8MZ2trxck...
# 47  https://api.spotify.com/v1/tracks/6FwkZ5lYdCUh...
# 48  https://api.spotify.com/v1/tracks/75QdM3nsnAlu...
# 49  https://api.spotify.com/v1/tracks/6Yg3gGtLuZTy...
# 50  https://api.spotify.com/v1/tracks/03XkLBYaV5Pl...
# 51  https://api.spotify.com/v1/tracks/6f3Slt0GbA2b...
# 52  https://api.spotify.com/v1/tracks/7uSdpAkxgB09...
# 53  https://api.spotify.com/v1/tracks/5nC2BQzszGGk...
# 54  https://api.spotify.com/v1/tracks/6GRDI9suQHik...
# 55  https://api.spotify.com/v1/tracks/0aZFEiDKLK2B...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4BZt...       63025
# 1   https://api.spotify.com/v1/audio-analysis/4f4H...      260227
# 2   https://api.spotify.com/v1/audio-analysis/2wy2...      205360
# 3   https://api.spotify.com/v1/audio-analysis/6zSw...      229219
# 4   https://api.spotify.com/v1/audio-analysis/7LYe...       62600
# 5   https://api.spotify.com/v1/audio-analysis/6bj4...      289493
# 6   https://api.spotify.com/v1/audio-analysis/6HKq...      185893
# 7   https://api.spotify.com/v1/audio-analysis/5KXS...      190417
# 8   https://api.spotify.com/v1/audio-analysis/5VWC...      451681
# 9   https://api.spotify.com/v1/audio-analysis/7LY0...      235493
# 10  https://api.spotify.com/v1/audio-analysis/4eES...      145053
# 11  https://api.spotify.com/v1/audio-analysis/79gy...      160136
# 12  https://api.spotify.com/v1/audio-analysis/09W3...      285773
# 13  https://api.spotify.com/v1/audio-analysis/1jOL...      242973
# 14  https://api.spotify.com/v1/audio-analysis/3HWx...      418200
# 15  https://api.spotify.com/v1/audio-analysis/4tc1...      488827
# 16  https://api.spotify.com/v1/audio-analysis/2hJR...       85307
# 17  https://api.spotify.com/v1/audio-analysis/4ndB...      294213
# 18  https://api.spotify.com/v1/audio-analysis/59jz...      315565
# 19  https://api.spotify.com/v1/audio-analysis/66Q3...      251573
# 20  https://api.spotify.com/v1/audio-analysis/6G4k...      223800
# 21  https://api.spotify.com/v1/audio-analysis/1VHY...      213160
# 22  https://api.spotify.com/v1/audio-analysis/4EgK...      252067
# 23  https://api.spotify.com/v1/audio-analysis/6NH8...      200080
# 24  https://api.spotify.com/v1/audio-analysis/3q2v...      723573
# 25  https://api.spotify.com/v1/audio-analysis/5eCz...      355293
# 26  https://api.spotify.com/v1/audio-analysis/6Lr9...      239173
# 27  https://api.spotify.com/v1/audio-analysis/1wl5...      193840
# 28  https://api.spotify.com/v1/audio-analysis/0h2l...      262008
# 29  https://api.spotify.com/v1/audio-analysis/2rhS...       51653
# 30  https://api.spotify.com/v1/audio-analysis/1b6r...      253787
# 31  https://api.spotify.com/v1/audio-analysis/0Ehh...      119893
# 32  https://api.spotify.com/v1/audio-analysis/1Vjl...      262040
# 33  https://api.spotify.com/v1/audio-analysis/37PS...      171600
# 34  https://api.spotify.com/v1/audio-analysis/2BQp...      419659
# 35  https://api.spotify.com/v1/audio-analysis/7GKi...      259213
# 36  https://api.spotify.com/v1/audio-analysis/01Zp...      283464
# 37  https://api.spotify.com/v1/audio-analysis/5gHu...      274080
# 38  https://api.spotify.com/v1/audio-analysis/0ezt...      316667
# 39  https://api.spotify.com/v1/audio-analysis/4Lgi...      162533
# 40  https://api.spotify.com/v1/audio-analysis/5Tnx...      167987
# 41  https://api.spotify.com/v1/audio-analysis/5eKf...      328933
# 42  https://api.spotify.com/v1/audio-analysis/0R3O...      145773
# 43  https://api.spotify.com/v1/audio-analysis/24up...      390639
# 44  https://api.spotify.com/v1/audio-analysis/7IBr...      305480
# 45  https://api.spotify.com/v1/audio-analysis/3ecV...      114920
# 46  https://api.spotify.com/v1/audio-analysis/6NF8...      313200
# 47  https://api.spotify.com/v1/audio-analysis/6Fwk...      155600
# 48  https://api.spotify.com/v1/audio-analysis/75Qd...      308080
# 49  https://api.spotify.com/v1/audio-analysis/6Yg3...      243187
# 50  https://api.spotify.com/v1/audio-analysis/03Xk...      148200
# 51  https://api.spotify.com/v1/audio-analysis/6f3S...      164000
# 52  https://api.spotify.com/v1/audio-analysis/7uSd...      285000
# 53  https://api.spotify.com/v1/audio-analysis/5nC2...      225427
# 54  https://api.spotify.com/v1/audio-analysis/6GRD...      190280
# 55  https://api.spotify.com/v1/audio-analysis/0aZF...      646239
#
#     time_signature
# 0                5
# 1                4
# 2                3
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                1
# 10               4
# 11               4
# 12               4
# 13               3
# 14               4
# 15               4
# 16               4
# 17               3
# 18               4
# 19               4
# 20               4
# 21               3
# 22               4
# 23               4
# 24               5
# 25               4
# 26               4
# 27               4
# 28               4
# 29               4
# 30               4
# 31               4
# 32               4
# 33               4
# 34               4
# 35               4
# 36               4
# 37               4
# 38               4
# 39               5
# 40               4
# 41               4
# 42               4
# 43               4
# 44               4
# 45               4
# 46               4
# 47               4
# 48               4
# 49               4
# 50               4
# 51               4
# 52               3
# 53               4
# 54               4
# 55               4
#
# [56 rows x 21 columns]
